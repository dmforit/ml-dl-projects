# %% [markdown]
# # Пути к данным

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cmc-ml-spotify-recommendations/sample_submission.csv
# /kaggle/input/cmc-ml-spotify-recommendations/added_info.csv
# /kaggle/input/cmc-ml-spotify-recommendations/audio_features.csv
# /kaggle/input/cmc-ml-spotify-recommendations/simple_pipeline.ipynb
# /kaggle/input/cmc-ml-spotify-recommendations/tracks_info.csv
# /kaggle/input/cmc-ml-spotify-recommendations/train.csv
# /kaggle/input/cmc-ml-spotify-recommendations/test.csv

# %% [markdown]
# # Код кодирования данных. Написан мной лично для научной работы.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.base import BaseEstimator, TransformerMixin
import sklearn.preprocessing as skpr
import category_encoders as ce
import numpy as np
import pandas as pd
import datetime
from copy import deepcopy
import math


class CircularEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, limits=None, fit_replace=True, tol=1e-8):
        self.limits = limits
        self.fit_replace = fit_replace
        self.tol = tol
        self._shape = (0, 0)

    def __repr__(self):
        return "Circular Encoder"

    def __str__(self):
        return "Circular Encoder"

    def fit(self, X, y=None):

        # Shape setting
        self._shape = self.__set_shape(X)

        # Defining limit
        if self.fit_replace:
            self.limits = self.__set_limits(X)

        return self

    def transform(self, X, y=None):
        if self.limits is None:
            return deepcopy(X)

        # column_names only for DataFrame
        column_names = None

        # cast to numpy array
        if isinstance(X, pd.DataFrame):
            X_ndarray = X.to_numpy().reshape(self._shape)
            column_names = np.zeros(2 * X.columns.shape[0], dtype=object)
        else:
            X_ndarray = X.reshape(self._shape)

        # main encoding
        result_sin = np.sin((2 * np.pi * X_ndarray) / self.limits)
        result_cos = np.cos((2 * np.pi * X_ndarray) / self.limits)

        result_sin[np.abs(result_sin) < self.tol] = 0.0
        result_cos[np.abs(result_cos) < self.tol] = 0.0

        # combine encoded arrays
        result = np.zeros((self._shape[0], self._shape[1] * 2))
        result[:, np.arange(0, result.shape[1], 2)] = result_sin
        result[:, np.arange(1, result.shape[1], 2)] = result_cos

        # set column_names names and return result
        if column_names is not None:
            column_names[np.arange(0, result.shape[1], 2)] = np.array([f'sin_{col}' for col in X.columns])
            column_names[np.arange(1, result.shape[1], 2)] = np.array([f'cos_{col}' for col in X.columns])
            return pd.DataFrame(result, columns=column_names).infer_objects()
        else:
            return result

    @staticmethod
    def __set_shape(X):
        if len(X.shape) == 1:
            return (X.shape[0], 1)
        elif len(X.shape) > 2:
            raise ValueError(f"You need 2 dimensions instead of {len(X.shape)}")
        else:
            return X.shape

    @staticmethod
    def __set_limits(X):
        if isinstance(X, pd.DataFrame):
            return np.max(np.abs(X.to_numpy()), axis=0) + 1
        else:
            return np.max(np.abs(X), axis=0) + 1

        
class CategoricalEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, cols=None, fit_replace=False, encoder='binary',
                 category_rate=0.1, rated_search=True, fast_mode=True,
                 confidence_level=0.99, worst_proportion=0.01, **encoder_params):

        self._hashing_enc_name = 'hashing'
        self._encoders_list = {'onehot': ce.OneHotEncoder,
                               'target_loo': ce.LeaveOneOutEncoder,
                               self._hashing_enc_name: ce.HashingEncoder,
                               'binary': ce.BinaryEncoder}
        self._target_encoders_list = np.array(['target_loo'])

        # stochastic approach
        eps = 1e-6
        confidence_level = max(eps, min(confidence_level, 1 - eps))
        worst_proportion = max(eps, min(worst_proportion, 1 - eps))
        self.fast_random_size = math.ceil(math.log(1 - confidence_level) / math.log(1 - worst_proportion))
        self.fast_mode = fast_mode

        self.cols = np.array(cols) if cols is not None else None
        self.fit_replace = fit_replace
        self.encoder_name = encoder
        self.category_rate = category_rate
        self.rated_search = rated_search
        self.encoder_params = encoder_params
        self._encoder = None

    def __repr__(self):
        return "CategoricalEncoder"

    def __str__(self):
        return "CategoricalEncoder"

    def fit(self, X, y=None, **fit_params):
        # defining categorical columns
        if self.cols is None or self.fit_replace:
            self.cols = self.define_cols(X)

        try:
            if not self.cols.shape[0]:
                return self
        except IndexError:
            raise IndexError("cols should be a numpy array")

        # save self.cols and get indices for X
        saved_cols = self.cols.copy()
        self.cols = self.cols_to_numeric(X)

        if not self.cols.shape[0]:
            self.cols = saved_cols
            return self

        # defining the encoder
        self.encoder_params['cols'] = X.columns[self.cols] if isinstance(X, pd.DataFrame) else self.cols
        self._encoder = self._encoders_list[self.encoder_name](**self.encoder_params)

        # transforming y if it's not numeric
        y_copy = None

        if y is not None:
            y_copy = deepcopy(y)
            if not self.is_y_approved(y_copy):
                y_copy = skpr.LabelEncoder().fit_transform(y_copy)

        # fitting the encoder
        self._encoder.fit(pd.DataFrame(X), y_copy, **fit_params)

        # self.cols backup
        self.cols = saved_cols
        return self

    def transform(self, X, y=None):
        try:
            if self.cols is None or not self.cols.shape[0] or self._encoder is None:
                return deepcopy(X)
        except IndexError:
            raise IndexError("cols should be a numpy array")

        # save self.cols and get indices for X
        saved_cols = self.cols.copy()
        self.cols = self.cols_to_numeric(X)

        if not self.cols.shape[0]:
            self.cols = saved_cols
            return deepcopy(X)

        # transforming y if it's not numeric
        y_copy = None

        if y is not None:
            y_copy = deepcopy(y)
            if not self.is_y_approved(y_copy):
                y_copy = skpr.LabelEncoder().fit_transform(y_copy)

        # checking whether it's a target encoder or not
        if self.encoder_name in self._target_encoders_list:
            result = self._encoder.transform(pd.DataFrame(X), y_copy, override_return_df=True)
        else:
            result = self._encoder.transform(pd.DataFrame(X), override_return_df=True)

        # adjusting the column names
        cols_before = self._encoder.get_feature_names_in()
        cols_after = self._encoder.get_feature_names_out()
        new_columns = self._rename_transformed_cols(cols_before, cols_after)

        result = result.rename(columns={cols_after[i]: new_columns[i] for i in range(cols_after.shape[0])})

        if isinstance(X, pd.DataFrame):
            # saving X dtypes
            not_cols = list(set(np.arange(X.shape[1])) - set(self.cols))
            saved_dtypes = X.dtypes.to_dict()
            unmodified_dtypes = dict([(X.columns[col], saved_dtypes[X.columns[col]]) for col in not_cols])

            # self.cols backup
            self.cols = saved_cols

            return result.astype(dtype=unmodified_dtypes)
        else:
            # self.cols backup
            self.cols = saved_cols

            return result.to_numpy()

    def fit_transform(self, X, y=None, **fit_params):
        # transforming y if it's not numeric
        y_copy = None

        if y is not None:
            y_copy = deepcopy(y)
            if not self.is_y_approved(y_copy):
                y_copy = skpr.LabelEncoder().fit_transform(y_copy)

        self.fit(X, y_copy, **fit_params)
        return self.transform(X, y_copy)

    def _rename_transformed_cols(self, before, after):
        if after is None:
            return np.array([])
        if self._encoder is None:
            return deepcopy(after)

        result = deepcopy(after)

        # hashing encoder unique renaming
        if self.encoder_name == self._hashing_enc_name:
            for i in range(self._encoder.n_components):
                result[i] = f'{self._hashing_enc_name}_{i}'
        else:
            # getting the columns transformed
            set_before = set(before)
            set_after = set(after)
            sample_names = set_before.intersection(set_after)

            # checking whether set is not empty
            if bool(sample_names):
                # renaming
                for num, col in enumerate(result):
                    if col not in sample_names:
                        result[num] = f'{self.encoder_name}_{result[num]}'

        return result

    def is_y_approved(self, y):
        try:
            y.astype(float)
            return True
        except (ValueError, TypeError):
            return False

    def cols_to_numeric(self, X):
        if self.cols is None or not self.cols.shape[0]:
            return np.array([])

        inds = self.cols.copy()

        try:
            inds = inds.astype(int)
            return inds
        except (ValueError, TypeError):
            if not isinstance(X, pd.DataFrame):
                return np.array([])
            else:
                columns_array = X.columns.to_numpy(dtype=object).copy()
                names_dict = dict((columns_array[i], i) for i in range(columns_array.shape[0]))
                inds = np.array([names_dict[name] for name in inds if name in names_dict])
                return inds

    def define_cols(self, X):
        # cast to pandas DataFrame with inferring object types
        if not isinstance(X, pd.DataFrame):
            X_df = pd.DataFrame(X).infer_objects()
        else:
            X_df = X.infer_objects()

        # check all the columns
        category_cols = []
        for num, col in enumerate(X_df):
            # if dtype is 'category'
            if pd.api.types.is_categorical_dtype(X_df[col]):
                category_cols.append(num)
            # checking object type (strings)
            elif pd.api.types.is_object_dtype(X_df[col]):
                # stochastic approach
                if self.fast_mode:
                    append_need = True
                    for i in range(self.fast_random_size):
                        if not self.is_one_word(X_df[col].iloc[np.random.randint(0, X_df.shape[0])]):
                            append_need = False
                            break
                    if append_need:
                        category_cols.append(num)
                else:
                    # basic approach
                    if np.all(np.vectorize(self.is_one_word)(X_df[col])):
                        category_cols.append(num)
            # checking numeric columns
            elif self.rated_search and pd.api.types.is_numeric_dtype(X_df[col]) and not pd.api.types.is_float_dtype(X_df[col]):
                if X_df[col].nunique() < self.category_rate * X_df.shape[0]:
                    category_cols.append(num)
        return np.array(category_cols)

    def is_one_word(self, s):
        if s is None or not isinstance(s, str):
            return False

        stripped_string = s.strip()
        if not stripped_string or ' ' in stripped_string:
            return False
        else:
            return True

    def get_cols(self):
        if self.cols is not None:
            return self.cols.copy()
        else:
            return np.array([])

    def get_encoder(self):
        return self.encoder_name

    def get_available_encoders(self):
        return np.array(list(self._encoders_list.keys()))


class NumericalEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, cols=None, fit_replace=False, encoder='standard', numeric_rate=0.1,
                 rated_search=True, only_float=True, **encoder_params):

        self._encoders_list = {'standard': skpr.StandardScaler,
                               'min_max': skpr.MinMaxScaler,
                               'normalizer': skpr.Normalizer,
                               'max_abs': skpr.MaxAbsScaler}

        self.only_float = only_float
        self.cols = np.array(cols) if cols is not None else None
        self.fit_replace = fit_replace
        self.encoder_name = encoder
        self.numeric_rate = numeric_rate
        self.rated_search = rated_search
        self.encoder_params = encoder_params
        self._encoder = None

    def __repr__(self):
        return "NumericalEncoder"

    def __str__(self):
        return "NumericalEncoder"

    def fit(self, X, y=None, **fit_params):
        # defining numerical columns
        if self.cols is None or self.fit_replace:
            self.cols = self.define_cols(X)

        try:
            if not self.cols.shape[0]:
                return self
        except IndexError:
            raise IndexError("cols should be a numpy array")

        # save self.cols and get indices for X
        saved_cols = self.cols.copy()
        self.cols = self.cols_to_numeric(X)

        if not self.cols.shape[0]:
            self.cols = saved_cols
            return self

        # defining the encoder
        self._encoder = self._encoders_list[self.encoder_name](**self.encoder_params)

        # fitting the encoder
        X_ndarray = X.to_numpy()[:, self.cols] if isinstance(X, pd.DataFrame) else X[:, self.cols]
        self._encoder.fit(X_ndarray, y, **fit_params)

        # self.cols backup
        self.cols = saved_cols

        return self

    def transform(self, X, y=None):
        try:
            if self.cols is None or not self.cols.shape[0] or self._encoder is None:
                return deepcopy(X)
        except IndexError:
            raise IndexError("cols should be a numpy array")

        # save self.cols and get indices for X
        saved_cols = self.cols.copy()
        self.cols = self.cols_to_numeric(X)

        if not self.cols.shape[0]:
            self.cols = saved_cols
            return deepcopy(X)

        column_names = None

        # cast to numpy array
        if isinstance(X, pd.DataFrame):
            X_ndarray = X.iloc[:, self.cols].to_numpy().astype(float)
            column_names = X.columns.to_numpy(dtype=object).copy()
        else:
            X_ndarray = X[:, self.cols].astype(float)

        # getting the resulting column names
        if column_names is not None:
            column_names[self.cols] = np.array([f'{self.encoder_name}_{name}' for name in column_names[self.cols]])

        # only numerical columns here
        result = self._encoder.transform(X_ndarray)

        if isinstance(X, pd.DataFrame):
            # saving X dtypes
            not_cols = list(set(np.arange(X.shape[1])) - set(self.cols))
            saved_dtypes = X.dtypes.to_dict()
            unmodified_dtypes = dict([(X.columns[col], saved_dtypes[X.columns[col]]) for col in not_cols])

            X_ndarray = deepcopy(X.to_numpy(dtype=object))
            X_ndarray[:, self.cols] = result
            result = pd.DataFrame(X_ndarray, columns=column_names).astype(dtype=unmodified_dtypes).infer_objects()
        else:
            X_ndarray = deepcopy(X)
            X_ndarray[:, self.cols] = result
            result = X_ndarray

        # self.cols backup
        self.cols = saved_cols

        return result

    def define_cols(self, X):
        # cast to pandas DataFrame with inferring object types
        if not isinstance(X, pd.DataFrame):
            X_df = pd.DataFrame(X).infer_objects()
        else:
            X_df = X.infer_objects()

        # check all the columns
        numeric_cols = []
        for num, col in enumerate(X_df):
            # if dtype is 'numeric'
            if pd.api.types.is_numeric_dtype(X_df[col]):
                # appending if float
                if pd.api.types.is_float_dtype(X_df[col]):
                    numeric_cols.append(num)
                elif not self.only_float:
                    # checking rated_search
                    if self.rated_search:
                        if X_df[col].nunique() >= self.numeric_rate * X_df.shape[0]:
                            numeric_cols.append(num)
                    else:
                        numeric_cols.append(num)
        return np.array(numeric_cols)

    def cols_to_numeric(self, X):
        if self.cols is None or not self.cols.shape[0]:
            return np.array([])

        inds = self.cols.copy()

        try:
            inds = inds.astype(int)
            return inds
        except (ValueError, TypeError):
            if not isinstance(X, pd.DataFrame):
                return np.array([])
            else:
                columns_array = X.columns.to_numpy(dtype=object).copy()
                names_dict = dict((columns_array[i], i) for i in range(columns_array.shape[0]))
                inds = np.array([names_dict[name] for name in inds if name in names_dict])
                return inds

    def get_cols(self):
        if self.cols is not None:
            return self.cols.copy()
        else:
            return np.array([])

    def get_encoder(self):
        return self.encoder_name

    def get_available_encoders(self):
        return np.array(list(self._encoders_list.keys()))

# %% [markdown]
# # Первый взгляд на данные

# %% [markdown]
# [Ссылка на соревнование](https://www.kaggle.com/competitions/cmc-ml-spotify-recommendations/leaderboard)

# %%
train_df = pd.read_csv('/kaggle/input/cmc-ml-spotify-recommendations/train.csv')
test_df = pd.read_csv('/kaggle/input/cmc-ml-spotify-recommendations/test.csv')
tracks_info_df = pd.read_csv('/kaggle/input/cmc-ml-spotify-recommendations/tracks_info.csv')
audio_features_df = pd.read_csv('/kaggle/input/cmc-ml-spotify-recommendations/audio_features.csv')
added_info_df = pd.read_csv('/kaggle/input/cmc-ml-spotify-recommendations/added_info.csv')
sample_submission_df = pd.read_csv('/kaggle/input/cmc-ml-spotify-recommendations/sample_submission.csv')

# %%
train_df
# Out:
#            index  playlist_id                track_id  exists
# 0        1050194        32931  07vS8obfeZbr8H4MgQfXR7       1
# 1         645550        35527  1PEqh7awkpuepLBSq8ZwqD       1
# 2        2630414        12203  7E8pPgBY84oDaXRcqODavR       0
# 3        3168314        21850  0Atml4huw4Fgyk6YSHiK4M       0
# 4        3144464        21391  4WYDmIZrwxBHdBYdvi5oQO       0
# ...          ...          ...                     ...     ...
# 2773057  2211111         4280  1CsJNkcfGXCUQhst9Wo4KL       0
# 2773058  3600703        29901  2VBGLp3N6JxIELDbbIhoSS       0
# 2773059  3879581        35199  5PEzhJIvmjFCFZcFZRze9S       0
# 2773060  1843050        29231  0kvWwRs634uP7K50NObw2h       1
# 2773061  3755897        32843  3G1RdjwDlaOxavwHfXW39g       0
#
# [2773062 rows x 4 columns]

# %%
test_df
# Out:
#            index  playlist_id                track_id
# 0              0        23073  09rm430z15znrby0txsnvx
# 1              1        27967  2cQvgkdRXcWLahNBM3luSD
# 2              2        20120  0lXbcnyo5T3VTa7gJ9fdGo
# 3              3        21054  0novBnPo3fjSPGK6RyHC56
# 4              4         5906  5yqevIi6idUAjBo67lJTtz
# ...          ...          ...                     ...
# 1188451  1188451        18736  31PPeK7rTkevgM3OYdBReA
# 1188452  1188452        17904  6OXilF9moyWn0YHX0iyKtr
# 1188453  1188453        27318  4oXMEXcjuypQAFFugKA7dB
# 1188454  1188454        31922  1KRu9rvn1NU4XCtUGyLGYm
# 1188455  1188455        24796  6bj8vnj6BubAKGkQ5iXbGb
#
# [1188456 rows x 3 columns]

# %%
audio_features_df
# Out:
#                             id  danceability   energy  key  loudness  mode  \
# 0       2roOWo3AxvYYFxVYSRl2Lw         0.725  0.91000    9    -5.175     1
# 1       33P76PS6skAOeQzYK77xss         0.520  0.96600    5    -5.845     0
# 2       7dS1UqsXYDkdVpA2zoHuY4         0.293  0.00546    8   -34.114     0
# 3       6eQFys5vvmGRvK0Gmb3QK8         0.414  0.00650    6   -34.234     1
# 4       6OOrm1Pi4ohW2IgxaPMXfL         0.702  0.80500    5    -5.432     0
# ...                        ...           ...      ...  ...       ...   ...
# 899928  0vzWDHKtEUfbvyVZTiFg4r         0.602  0.65400    7    -6.592     1
# 899929  3VvGP9ldsvUyhSYwCh5GL3         0.444  0.13100    0   -17.910     1
# 899930  54HMQ6LzInyFQaxv6sK2TG         0.682  0.73600    1    -5.004     1
# 899931  3gp1UtKF9QwTwg6VUxNGmz         0.280  0.89600   10   -10.444     0
# 899932  29s7WyAxEew32Sdxv5O9S0         0.493  0.14500    9   -23.753     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 0            0.0828      0.215000           0.02450    0.0747   0.8080
# 1            0.0601      0.000090           0.19700    0.2970   0.0382
# 2            0.0660      0.962000           0.82900    0.0853   0.2200
# 3            0.0360      0.994000           0.94100    0.1060   0.1570
# 4            0.0427      0.131000           0.00000    0.3430   0.7780
# ...             ...           ...               ...       ...      ...
# 899928       0.0283      0.020400           0.00126    0.2310   0.0882
# 899929       0.0377      0.945000           0.60200    0.1210   0.1690
# 899930       0.0458      0.017000           0.00000    0.1400   0.8120
# 899931       0.0703      0.000146           0.73300    0.1900   0.1670
# 899932       0.0362      0.990000           0.96100    0.0947   0.3370
#
#           tempo  duration_ms  time_signature
# 0        92.717       156293               4
# 1       128.020       241875               4
# 2        99.164        80100               4
# 3        71.737       135187               4
# 4       139.901       173520               4
# ...         ...          ...             ...
# 899928  103.025       181893               4
# 899929  111.149       164773               4
# 899930  150.021       209748               4
# 899931   87.261        97000               4
# 899932   80.431       103132               4
#
# [899933 rows x 14 columns]

# %%
added_info_df
# Out:
#          playlist_id                track_id              added_at  \
# 0                254  2aQpISWUBToaF84DDiTeRV  2024-02-29T16:53:53Z
# 1              17014  6EipcpKMRufBSIGLZqmmwz  2021-01-29T10:04:19Z
# 2              18570  5IJnj6Um7jVuRPT4WGj1z6  2016-02-15T14:57:19Z
# 3              14643  3vvvpZ3ez7uCEM5uhkj1ou  2024-01-25T16:19:12Z
# 4              12131  0P0IfSuzTC6bLUsHjmDuvW  2023-10-07T14:02:31Z
# ...              ...                     ...                   ...
# 1399258        19350  0W7AbEauB7cP4pidLclApe  2022-02-09T00:40:20Z
# 1399259        14587  6Vjk8MNXpQpi0F4BefdTyq  2022-07-05T15:46:03Z
# 1399260        27434  7795WJLVKJoAyVoOtCWqXN  2022-12-22T19:32:22Z
# 1399261         8894  5xJ0KrDk6kjRP4GjAfG3VS  2022-01-10T11:26:03Z
# 1399262        20947  4HXnGPP8YcpXGCQavmTpXi  2016-04-03T08:01:18Z
#
#          added_by_id added_by_type
# 0                590          user
# 1               3013          user
# 2                399          user
# 3               2449          user
# 4               1014          user
# ...              ...           ...
# 1399258         3042          user
# 1399259         2449          user
# 1399260          857          user
# 1399261         1817          user
# 1399262          280          user
#
# [1399263 rows x 5 columns]

# %%
tracks_info_df.track_album_album[0]
# Out:
# "{'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FqTuN42w2zGw4Pzd50yaS'}, 'href': 'https://api.spotify.com/v1/artists/5FqTuN42w2zGw4Pzd50yaS', 'id': '5FqTuN42w2zGw4Pzd50yaS', 'name': 'Reckol', 'type': 'artist', 'uri': 'spotify:artist:5FqTuN42w2zGw4Pzd50yaS'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CPZWzcKiOKkHn4L2XI4i2'}, 'href': 'https://api.spotify.com/v1/artists/6CPZWzcKiOKkHn4L2XI4i2', 'id': '6CPZWzcKiOKkHn4L2XI4i2', 'name': 'cakal', 'type': 'artist', 'uri': 'spotify:artist:6CPZWzcKiOKkHn4L2XI4i2'}], 'available_markets': [], 'external_urls': {'spotify': 'https://open.spotify.com/album/6LpuMzcAiFIOBr4ijkpPuQ'}, 'href': 'https://api.spotify.com/v1/albums/6LpuMzcAiFIOBr4ijkpPuQ', 'id': '6LpuMzcAiFIOBr4ijkpPuQ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27360c5021f2e5cc64a8a700902', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0260c5021f2e5cc64a8a700902', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485160c5021f2e5cc64a8a700902', 'width': 64}], 'name': 'Perros Blancos Freestyle', 'release_date': '2021-04-02', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:6LpuMzcAiFIOBr4ijkpPuQ'}"

# %% [markdown]
# # Предобработка данных

# %%
import warnings, gc
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## added_info_df

# %%
# Удалим лишний столбец и проведём парсинг временных данных
added_info_df = added_info_df.drop('added_by_type', axis=1)
added_info_df['added_at'] = pd.to_datetime(added_info_df['added_at'])
added_info_df['added_at_year'] = added_info_df['added_at'].dt.year
added_info_df['added_at_month'] = added_info_df['added_at'].dt.month
added_info_df['added_at_day'] = added_info_df['added_at'].dt.day
added_info_df['added_at_hour'] = added_info_df['added_at'].dt.hour
added_info_df = added_info_df.drop('added_at', axis=1)

# Кодирование периодических признаков
encoded_month = CircularEncoder(12).fit_transform(added_info_df['added_at_month'].to_frame())
encoded_day = CircularEncoder(31).fit_transform(added_info_df['added_at_day'].to_frame())
encoded_hour =  CircularEncoder(24).fit_transform(added_info_df['added_at_hour'].to_frame())
added_info_df = pd.concat([added_info_df, encoded_month, encoded_day, encoded_hour], axis=1)
added_info_df = added_info_df.drop(['added_at_month', 'added_at_day', 'added_at_hour'], axis=1)

# Группируем по объектам обучающей выборки
result_added_info = added_info_df.groupby(['track_id', 'playlist_id']).agg(lambda x: x.tolist()).reset_index()
result_added_info.added_at_year = result_added_info.added_at_year.apply(lambda x: sum(x) / len(x)).astype(int)
result_added_info.added_by_id = result_added_info.added_by_id.apply(lambda x: sum(x) / len(x)).astype(int)

for col in result_added_info.columns:
    if col[:3] in ['cos', 'sin']:
        result_added_info[col] = result_added_info[col].apply(lambda x: sum(x) / len(x))
        
# Убираем дубликаты
result_added_info.drop_duplicates(keep='first', inplace=True)

# %%
# Проверяем наличие пропусков в данных
nan_columns = []
for col in result_added_info.columns:
    if result_added_info[col][result_added_info[col].isna() == True].shape[0] > 0:
        nan_columns.append(col)
if len(nan_columns) == 0:
    print('Пропусков нет')
else:
    print('Пропуски имеются в следующих признаках: ', ', '.join(nan_columns))
# Out:
# Пропусков нет

# %%
result_added_info
# Out:
#                        track_id  playlist_id  added_by_id  added_at_year  \
# 0        0006Rv1e2Xfh6QooyKJqKS        24238          868           2023
# 1        0007ftg5erIndAnrITMGON         1334         1382           2019
# 2        000C3ZY8325A4yktxnnwCl        30244         2863           2017
# 3        000FetCrS9eDC1Ii1lCLfT        12634         2227           2020
# 4        000HoCMkO5w5BuqgU6TXUD         9889         1751           2023
# ...                         ...          ...          ...            ...
# 1388818  7zzoxJbgjme3366mOp5UnH        20191         2446           2019
# 1388819  7zzqH8TtAQExYITjk0b7e8         2054          437           2018
# 1388820  7zzrXzx0A7C7RriCE8tVIe        25797         1552           2023
# 1388821  7zztYl9vdJP0R8w7l9XEbk         8536         1664           2023
# 1388822  7zzwpbkEubdwGkuCjEdRCK        24507         2602           2019
#
#          sin_added_at_month  cos_added_at_month  sin_added_at_day  \
# 0                 -0.239316           -0.970942          0.980785
# 1                  0.992709            0.120537          0.831470
# 2                  0.663123           -0.748511         -0.195090
# 3                 -0.992709            0.120537         -0.923880
# 4                  0.822984            0.568065          0.195090
# ...                     ...                 ...               ...
# 1388818            0.663123           -0.748511         -0.980785
# 1388819           -0.464723            0.885456          0.707107
# 1388820            0.992709            0.120537         -0.923880
# 1388821            0.992709            0.120537          0.980785
# 1388822            0.464723            0.885456          0.000000
#
#          cos_added_at_day  sin_added_at_hour  cos_added_at_hour
# 0               -0.195090          -0.965926           0.258819
# 1               -0.555570          -0.965926           0.258819
# 2                0.980785           0.500000           0.866025
# 3               -0.382683           0.000000           1.000000
# 4               -0.980785          -1.000000           0.000000
# ...                   ...                ...                ...
# 1388818          0.195090           0.707107          -0.707107
# 1388819          0.707107          -0.707107           0.707107
# 1388820         -0.382683          -0.258819          -0.965926
# 1388821         -0.195090           0.866025           0.500000
# 1388822         -1.000000          -0.258819          -0.965926
#
# [1388823 rows x 10 columns]

# %% [markdown]
# # audio_features_df

# %%
# Убираем дубликаты
audio_features_df.drop_duplicates(keep='first', inplace=True)

# Проверяем наличие пропусков в данных
nan_columns = []
for col in audio_features_df.columns:
    if audio_features_df[col][audio_features_df[col].isna() == True].shape[0] > 0:
        nan_columns.append(col)
if len(nan_columns) == 0:
    print('Пропусков нет')
else:
    print('Пропуски имеются в следующих признаках: ', ', '.join(nan_columns))

# Переименование колонки id
audio_features_df = audio_features_df.rename(columns={'id': 'track_id'})
# Out:
# Пропусков нет

# %%
# Кодирование вещественных признаков
audio_features_nums = np.array(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms'])
result_audio_features = NumericalEncoder(cols=audio_features_nums).fit_transform(audio_features_df)

# %%
result_audio_features
# Out:
#                       track_id  standard_danceability  standard_energy  key  \
# 0       2roOWo3AxvYYFxVYSRl2Lw               0.915699         1.299411    9
# 1       33P76PS6skAOeQzYK77xss              -0.158443         1.493671    5
# 2       7dS1UqsXYDkdVpA2zoHuY4              -1.347858        -1.838363    8
# 3       6eQFys5vvmGRvK0Gmb3QK8              -0.713853        -1.834755    6
# 4       6OOrm1Pi4ohW2IgxaPMXfL               0.795185         0.935175    5
# ...                        ...                    ...              ...  ...
# 899229  0vzWDHKtEUfbvyVZTiFg4r               0.271214         0.411369    7
# 899230  3VvGP9ldsvUyhSYwCh5GL3              -0.556661        -1.402875    0
# 899231  54HMQ6LzInyFQaxv6sK2TG               0.690391         0.695820    1
# 899232  3gp1UtKF9QwTwg6VUxNGmz              -1.415974         1.250846   10
# 899233  29s7WyAxEew32Sdxv5O9S0              -0.299915        -1.354310    9
#
#         standard_loudness  mode  standard_speechiness  standard_acousticness  \
# 0                0.815225     1              0.022212              -0.531288
# 1                0.718698     0             -0.219975              -1.103402
# 2               -3.354010     0             -0.157027               1.457301
# 3               -3.371298     1             -0.477099               1.542488
# 4                0.778199     0             -0.405616              -0.754905
# ...                   ...   ...                   ...                    ...
# 899229           0.611078     1             -0.559250              -1.049333
# 899230          -1.019503     1             -0.458961               1.412045
# 899231           0.839861     1             -0.372542              -1.058384
# 899232           0.056121     0             -0.111151              -1.103251
# 899233          -1.861303     0             -0.474965               1.531839
#
#         standard_instrumentalness  standard_liveness  standard_valence  \
# 0                       -0.704860          -0.686636          1.368767
# 1                       -0.264251           0.677099         -1.472436
# 2                        1.350038          -0.621608         -0.801443
# 3                        1.636114          -0.494621         -1.033965
# 4                       -0.767439           0.959293          1.258042
# ...                           ...                ...               ...
# 899229                  -0.764221           0.272212         -1.287895
# 899230                   0.770222          -0.402601         -0.989675
# 899231                  -0.767439          -0.286042          1.383530
# 899232                   1.104829           0.020691         -0.997057
# 899233                   1.687199          -0.563942         -0.369615
#
#         standard_tempo  standard_duration_ms  time_signature
# 0            -0.868776             -0.566747               4
# 1             0.288894              0.103000               4
# 2            -0.657364             -1.163019               4
# 3            -1.556761             -0.731919               4
# 4             0.678500             -0.431932               4
# ...                ...                   ...             ...
# 899229       -0.530752             -0.366407               4
# 899230       -0.264347             -0.500385               4
# 899231        1.010360             -0.148419               4
# 899232       -1.047692             -1.030763               4
# 899233       -1.271664             -0.982775               4
#
# [899234 rows x 14 columns]

# %% [markdown]
# ## tracks_info_df

# %%
track_artists = [eval(dict_str) for dict_str in tracks_info_df.track_artists.to_list()]
album_album = [eval(dict_str) for dict_str in tracks_info_df.track_album_album.to_list()]

# %%
for i in range(len(track_artists)):
    track_artists[i] = [elem['id'] for elem in track_artists[i]]

# %%
track_artists = [elem[0] for elem in track_artists]

# %%
track_artists = np.array(track_artists)

# %%
album_type = [elem['album_type'] for elem in album_album]
release_date = [elem['release_date'] for elem in album_album]
album_id = [elem['id'] for elem in album_album]

# %%
track_artists = pd.DataFrame(track_artists, columns=['artists_ids'])

# %%
album_type = pd.DataFrame(album_type, columns=['type_album'])

# %%
release_date = pd.DataFrame(release_date, columns=['release_date'])

# %%
album_id = pd.DataFrame(album_id, columns=['album_id'])

# %%
# Убираем ненужные признаки
drop_columns = ['track_album_type', 'track_album_track', 'track_album_is_local', 
                'track_album_episode', 'track_album_artists', 'track_album_name', 
                'track_album_id', 'track_album_disc_number', 'track_album_duration_ms', 
                'track_album_explicit', 'track_album_popularity', 'track_album_track_number',
                'track_type', 'track_episode', 'track_is_local', 'track_track', 'track_name',
                'track_disc_number', 'track_available_markets', 'track_album_album', 'track_artists']

tracks_info_df = tracks_info_df.drop(drop_columns, axis=1)

# Изменяем тип данных для категориальных признаков
for col in tracks_info_df.columns:
    if tracks_info_df[col].dtype == np.float64:
        tracks_info_df[col] = tracks_info_df[col].astype(int)
    elif tracks_info_df[col].dtype == bool:
        tracks_info_df[col] = tracks_info_df[col].astype(int)

# Проверяем наличие пропусков в данных
nan_columns = []
for col in tracks_info_df.columns:
    if tracks_info_df[col][tracks_info_df[col].isna() == True].shape[0] > 0:
        nan_columns.append(col)
if len(nan_columns) == 0:
    print('Пропусков нет')
else:
    print('Пропуски имеются в следующих признаках: ', ', '.join(nan_columns))
# Out:
# Пропусков нет

# %%
tracks_info_num = ['track_duration_ms']
result_tracks_info = NumericalEncoder(cols=tracks_info_num).fit_transform(tracks_info_df)

# %%
result_tracks_info = pd.concat([result_tracks_info, album_type, release_date, track_artists, album_id], axis=1)

# %%
result_tracks_info
# Out:
#                       track_id  standard_track_duration_ms  track_explicit  \
# 0       5SrPeOqm3SBecyiAsI9HTT                   -0.652868               1
# 1       0YfvJaebmC1ch3vMik9yuA                    2.112132               0
# 2       6bSpavIeJURyGBNMUlJydq                    0.188676               0
# 3       0fIBz9zLZGqrCMaAUskhk2                    2.567852               0
# 4       2fG23IIy7rYN8eMNbAHcS2                   -0.241374               0
# ...                        ...                         ...             ...
# 899707  2r6pzLfa4huH3L3w7hzZXx                   -0.049473               0
# 899708  0IEhU1bRVEqWCfb6Fy6w67                   -0.647332               0
# 899709  5WRNi2GaPQa1GBAKxKHJfS                    0.363925               1
# 899710  0VwdSxxhCGc0MFvndnGw6T                    0.034373               0
# 899711  3lCXZZaNFTTMxNN45memEB                   -0.259767               0
#
#         track_popularity  track_track_number   type_album release_date  \
# 0                      0                   1       single   2021-04-02
# 1                     40                   1        album   2021-02-03
# 2                     12                  15        album   2015-02-10
# 3                     20                   4        album   2000-01-01
# 4                     52                   9        album   2013-01-01
# ...                  ...                 ...          ...          ...
# 899707                21                   1        album         1991
# 899708                39                   1       single   2018-07-28
# 899709                 0                   7        album   2018-05-18
# 899710                 3                  11  compilation   2015-11-09
# 899711                17                   1       single   2021-03-19
#
#                    artists_ids                album_id
# 0       5FqTuN42w2zGw4Pzd50yaS  6LpuMzcAiFIOBr4ijkpPuQ
# 1       4Cru1k3r3v36wCWfcJMK2y  094repVXEwkzPNg56jsJgs
# 2       1jjpkAHC8bd9fRFfgKyYLP  3WVvNhEvAjTKjYUNubfHtd
# 3       6MF58APd3YV72Ln2eVg710  47rGmuTbcsdAzRmyTlOvUp
# 4       70kkdajctXSbqSMJbQO424  6IGpQUt0KNi5rBUXZZOFI6
# ...                        ...                     ...
# 899707  4Csr2RlQUb4MODz2R3Usn7  3yaUYGJ1ol0Katez71WNSc
# 899708  0cIbGrllcQSKTM3AxUxHiL  7kwkWQEne0CZCmMTa7ReiW
# 899709  6YxtMx8c5tjVRRHsqjEERp  3BcX5gCQZblSPagIBuoVBr
# 899710  3NUsiT2JSyaWAnWaXxDzhQ  3wICzSqLpPBjIawEPSqq8L
# 899711  6V8FJ4jrLkendobaeT99an  1XeI84AYgvjfpTAHSy8QFo
#
# [899712 rows x 9 columns]

# %% [markdown]
# # Построение обучающей, валидационной и тестовой выборки

# %% [markdown]
# Синтезируем выборку для *train* и *test*

# %%
# Обучающая выборка
X_train = train_df.drop(['exists', 'index'], axis=1)
y_train = train_df['exists'].copy()

# Добавляем необходимые признаки
X_train = pd.merge(X_train, result_audio_features, on='track_id', how='left')
X_train = pd.merge(X_train, result_tracks_info, on='track_id', how='left')

# Тестовая выборка
X_test = test_df.drop('index', axis=1)

# Добавляем необходимые признаки
X_test = pd.merge(X_test, result_audio_features, on='track_id', how='left')
X_test = pd.merge(X_test, result_tracks_info, on='track_id', how='left')

# %%
# Заполняем пропуски (Train)
for col in X_train.columns:
    if X_train[col][X_train[col].isna() == True].shape[0] > 0:
        print(col)
        X_test[col] = X_test[col].fillna(X_train[col].mean(skipna=True))
        X_train[col] = X_train[col].fillna(X_train[col].mean(skipna=True))
# Out:
# standard_danceability
# standard_energy
# key
# standard_loudness
# mode
# standard_speechiness
# standard_acousticness
# standard_instrumentalness
# standard_liveness
# standard_valence
# standard_tempo
# standard_duration_ms
# time_signature

# %%
for col in X_train.columns:
    if X_test[col][X_test[col].isna() == True].shape[0] > 0:
        print(col)

# %%
X_train['key'] = X_train['key'].astype(int)
X_train['mode'] = X_train['mode'].astype(int)
X_train['time_signature'] = X_train['time_signature'].astype(int)

# %%
X_test['key'] = X_test['key'].astype(int)
X_test['mode'] = X_test['mode'].astype(int)
X_test['time_signature'] = X_test['time_signature'].astype(int)

# %%
X_train['track_popularity'] = X_train['track_popularity'].astype(np.float64)
X_test['track_popularity'] = X_test['track_popularity'].astype(np.float64)

# %%
X_train
# Out:
#          playlist_id                track_id  standard_danceability  \
# 0              32931  07vS8obfeZbr8H4MgQfXR7              -0.928681
# 1              35527  1PEqh7awkpuepLBSq8ZwqD               1.015253
# 2              12203  7E8pPgBY84oDaXRcqODavR               1.030973
# 3              21850  0Atml4huw4Fgyk6YSHiK4M               0.281693
# 4              21391  4WYDmIZrwxBHdBYdvi5oQO               1.104329
# ...              ...                     ...                    ...
# 2773057         4280  1CsJNkcfGXCUQhst9Wo4KL               0.376008
# 2773058        29901  2VBGLp3N6JxIELDbbIhoSS               0.051146
# 2773059        35199  5PEzhJIvmjFCFZcFZRze9S               1.182924
# 2773060        29231  0kvWwRs634uP7K50NObw2h              -0.682414
# 2773061        32843  3G1RdjwDlaOxavwHfXW39g               0.470323
#
#          standard_energy  key  standard_loudness  mode  standard_speechiness  \
# 0              -1.430626    7          -0.628066     1             -0.426954
# 1              -0.285884    5          -0.164738     1             -0.489902
# 2               1.188406    9           0.810327     0             -0.480299
# 3              -0.178347    7           0.538323     1             -0.481366
# 4              -0.306697    0          -0.018363     1             -0.207172
# ...                  ...  ...                ...   ...                   ...
# 2773057         0.917830    9           0.505187     0             -0.492035
# 2773058         1.223095    9           0.167631     1             -0.271186
# 2773059         0.456464    1           0.838132     0              3.726503
# 2773060         0.938644    4           0.247734     1             -0.207172
# 2773061        -0.521770    0           0.470610     1             -0.576321
#
#          standard_acousticness  standard_instrumentalness  ...  \
# 0                     1.420031                  -0.767439  ...
# 1                     0.565497                   0.307902  ...
# 2                    -0.892269                  -0.766083  ...
# 3                    -0.837430                  -0.767439  ...
# 4                    -0.939655                   1.462425  ...
# ...                        ...                        ...  ...
# 2773057              -1.101247                  -0.722995  ...
# 2773058              -1.017388                  -0.518910  ...
# 2773059              -0.443439                  -0.767439  ...
# 2773060              -0.862720                  -0.126321  ...
# 2773061               1.116552                  -0.767439  ...
#
#          standard_duration_ms  time_signature  standard_track_duration_ms  \
# 0                   -0.061827               4                   -0.058537
# 1                    0.088014               4                    0.082791
# 2                   -0.516044               4                   -0.486925
# 3                   -0.082565               4                   -0.078088
# 4                    1.284547               4                    1.211277
# ...                       ...             ...                         ...
# 2773057             -0.198410               4                   -0.187354
# 2773058             -0.007719               4                   -0.007499
# 2773059             -0.555204               4                   -0.523859
# 2773060             -0.026767               4                   -0.025463
# 2773061             -0.079044               4                   -0.074767
#
#          track_explicit  track_popularity  track_track_number   type_album  \
# 0                     0               0.0                   2       single
# 1                     0              73.0                   3        album
# 2                     0               0.0                   1       single
# 3                     0               0.0                  11        album
# 4                     0               7.0                   3  compilation
# ...                 ...               ...                 ...          ...
# 2773057               0               5.0                  14  compilation
# 2773058               0               0.0                   2        album
# 2773059               0              44.0                   3       single
# 2773060               0               2.0                  12        album
# 2773061               0              12.0                   5       single
#
#          release_date             artists_ids                album_id
# 0          2018-12-05  1r1uxoy19fzMxunt3ONAkG  1y2zWE0vkqUSXZ92lFAO2P
# 1          1996-04-16  2EfG2EoT8GFJrMiilbTVl2  1VzYTrtId9CgUTo7VQBFbL
# 2          2014-07-07  3cnAJv9gydgm52KFIsdvO8  1cbvOYy11NyKZfwXGCJCVA
# 3          2001-01-24  7y5ZQx8XgtDa1r7KAkplOZ  1bTlGTasuKVa8QuHhYn1Ac
# 4          2014-10-03  7hjgsaJuLvrObwm39oEfLq  6LBktkX9tgfoGeRZBAt9TI
# ...               ...                     ...                     ...
# 2773057    2024-02-23  6CpUfSiqmNciuYLQ1CxH9e  2m1OxoQ0Uk2XXcC19Cyub3
# 2773058          2007  1fa0cOhromAZdq2xRA4vv8  6qBZW0ODvRdfJfF8Xb5oY7
# 2773059    2020-02-14  2NfSBtmWe7oPw1EmetJVso  4zzCQHjlhEEAidzfNRONJL
# 2773060    2017-10-20  0V9fDzVz0TmKcWZLKyjEXx  7iPbUBbGyQlVnFBpf8ahdz
# 2773061    2022-10-21  4vEpUOtKWtpotWkuv0Vlx4  1P8k4am7eNKqNQAA0EBXjD
#
# [2773062 rows x 23 columns]

# %%
# X_train = X_train.drop('release_date', axis=1)
# X_test = X_test.drop('release_date', axis=1)

# X_train = X_train.drop('album_ids', axis=1)
# X_test = X_test.drop('album_ids', axis=1)

# %%
# import gc
# gc.collect()

# %%
# del new_list_album

# %%
# del new_list

# %%
cat_inds = []

for i, col in enumerate(X_train.columns):
    if X_train[col].dtype == np.int64 or X_train[col].dtype == object:
        cat_inds.append(i)

# %%
cat_inds
# Out:
# [0, 1, 4, 6, 14, 16, 18, 19, 20, 21, 22]

# %%
# X_train.to_csv('/kaggle/working/dataset.csv', index=False)
# X_train = X_train.drop('track_id', axis=1)

# %%
from sklearn.model_selection import train_test_split

data_train, data_val, target_train, target_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# # Обучение

# %% [markdown]
# ## CatBoost

# %%
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import f1_score

train_dataset = Pool(data=data_train,
                     label=target_train,
                     cat_features=cat_inds)

eval_dataset = Pool(data=data_val,
                    label=target_val,
                    cat_features=cat_inds)

model = CatBoostClassifier(task_type="GPU",
                           devices=[0, 1],
                           num_trees=1000,
                           learning_rate=0.46,
                           eval_metric='F1')
model.fit(train_dataset,
          eval_set=eval_dataset)

# Make predictions on the validation data
preds_proba = model.predict_proba(data_val)
preds = np.argmax(preds_proba, axis=1)

# Calculate F1 score on the training data
f1_val = f1_score(target_val, preds)
print(f"F1 Score on Val Data: {f1_val:.2f}")

# Make predictions on the training data
preds_proba = model.predict_proba(data_train)
preds = np.argmax(preds_proba, axis=1)

# Calculate F1 score on the training data
f1_train = f1_score(target_train, preds)
print(f"F1 Score on Train Data: {f1_train:.2f}")

# Make predictions on the data
preds_proba = model.predict_proba(X_train)
preds = np.argmax(preds_proba, axis=1)

# Calculate F1 score on the data
f1_data = f1_score(y_train, preds)
print(f"F1 Score on X_train: {f1_data:.2f}")
# Out:
# 0:	learn: 0.7609379	test: 0.6985457	best: 0.6985457 (0)	total: 490ms	remaining: 8m 9s
# 1:	learn: 0.8000621	test: 0.7697183	best: 0.7697183 (1)	total: 907ms	remaining: 7m 32s
# 2:	learn: 0.8041458	test: 0.7673401	best: 0.7697183 (1)	total: 1.21s	remaining: 6m 40s
# 3:	learn: 0.8161546	test: 0.7812623	best: 0.7812623 (3)	total: 1.5s	remaining: 6m 13s
# 4:	learn: 0.8201883	test: 0.7768167	best: 0.7812623 (3)	total: 1.83s	remaining: 6m 3s
# 5:	learn: 0.8285045	test: 0.7930470	best: 0.7930470 (5)	total: 2.11s	remaining: 5m 50s
# 6:	learn: 0.8320754	test: 0.7990169	best: 0.7990169 (6)	total: 2.37s	remaining: 5m 36s
# 7:	learn: 0.8350222	test: 0.8069258	best: 0.8069258 (7)	total: 2.6s	remaining: 5m 22s
# 8:	learn: 0.8408097	test: 0.8141624	best: 0.8141624 (8)	total: 2.82s	remaining: 5m 10s
# 9:	learn: 0.8443778	test: 0.8198651	best: 0.8198651 (9)	total: 3.1s	remaining: 5m 6s
# 10:	learn: 0.8465854	test: 0.8223406	best: 0.8223406 (10)	total: 3.52s	remaining: 5m 16s
# 11:	learn: 0.8482352	test: 0.8241838	best: 0.8241838 (11)	total: 3.72s	remaining: 5m 6s
# 12:	learn: 0.8519505	test: 0.8251253	best: 0.8251253 (12)	total: 3.93s	remaining: 4m 58s
# 13:	learn: 0.8531602	test: 0.8273339	best: 0.8273339 (13)	total: 4.19s	remaining: 4m 55s
# 14:	learn: 0.8541739	test: 0.8350944	best: 0.8350944 (14)	total: 4.55s	remaining: 4m 58s
# 15:	learn: 0.8549591	test: 0.8352369	best: 0.8352369 (15)	total: 4.75s	remaining: 4m 52s
# 16:	learn: 0.8560903	test: 0.8368447	best: 0.8368447 (16)	total: 5.07s	remaining: 4m 53s
# 17:	learn: 0.8620830	test: 0.8452075	best: 0.8452075 (17)	total: 5.44s	remaining: 4m 56s
# 18:	learn: 0.8627985	test: 0.8462085	best: 0.8462085 (18)	total: 5.7s	remaining: 4m 54s
# 19:	learn: 0.8634265	test: 0.8468446	best: 0.8468446 (19)	total: 5.87s	remaining: 4m 47s
# 20:	learn: 0.8670012	test: 0.8523230	best: 0.8523230 (20)	total: 6.21s	remaining: 4m 49s
# 21:	learn: 0.8679142	test: 0.8540607	best: 0.8540607 (21)	total: 6.55s	remaining: 4m 51s
# 22:	learn: 0.8713586	test: 0.8595078	best: 0.8595078 (22)	total: 6.87s	remaining: 4m 51s
# 23:	learn: 0.8718349	test: 0.8598620	best: 0.8598620 (23)	total: 7.1s	remaining: 4m 48s
# 24:	learn: 0.8729259	test: 0.8628969	best: 0.8628969 (24)	total: 7.47s	remaining: 4m 51s
# 25:	learn: 0.8732897	test: 0.8639444	best: 0.8639444 (25)	total: 7.75s	remaining: 4m 50s
# 26:	learn: 0.8736798	test: 0.8643681	best: 0.8643681 (26)	total: 8.03s	remaining: 4m 49s
# 27:	learn: 0.8758821	test: 0.8674624	best: 0.8674624 (27)	total: 8.34s	remaining: 4m 49s
# 28:	learn: 0.8767452	test: 0.8684168	best: 0.8684168 (28)	total: 8.69s	remaining: 4m 51s
# 29:	learn: 0.8774972	test: 0.8693864	best: 0.8693864 (29)	total: 9.02s	remaining: 4m 51s
# 30:	learn: 0.8792962	test: 0.8715381	best: 0.8715381 (30)	total: 9.37s	remaining: 4m 52s
# 31:	learn: 0.8795565	test: 0.8714207	best: 0.8715381 (30)	total: 9.61s	remaining: 4m 50s
# 32:	learn: 0.8815949	test: 0.8743600	best: 0.8743600 (32)	total: 9.92s	remaining: 4m 50s
# 33:	learn: 0.8823694	test: 0.8751882	best: 0.8751882 (33)	total: 10.3s	remaining: 4m 52s
# 34:	learn: 0.8826972	test: 0.8755022	best: 0.8755022 (34)	total: 10.6s	remaining: 4m 53s
# 35:	learn: 0.8839743	test: 0.8773952	best: 0.8773952 (35)	total: 10.9s	remaining: 4m 53s
# 36:	learn: 0.8848038	test: 0.8785399	best: 0.8785399 (36)	total: 11.2s	remaining: 4m 51s
# 37:	learn: 0.8859232	test: 0.8798561	best: 0.8798561 (37)	total: 11.4s	remaining: 4m 49s
# 38:	learn: 0.8861586	test: 0.8799682	best: 0.8799682 (38)	total: 11.6s	remaining: 4m 46s
# 39:	learn: 0.8863839	test: 0.8802408	best: 0.8802408 (39)	total: 11.9s	remaining: 4m 46s
# 40:	learn: 0.8866491	test: 0.8803269	best: 0.8803269 (40)	total: 12.2s	remaining: 4m 45s
# 41:	learn: 0.8867813	test: 0.8805899	best: 0.8805899 (41)	total: 12.5s	remaining: 4m 45s
# 42:	learn: 0.8870980	test: 0.8806866	best: 0.8806866 (42)	total: 12.8s	remaining: 4m 44s
# 43:	learn: 0.8879605	test: 0.8819695	best: 0.8819695 (43)	total: 13s	remaining: 4m 41s
# 44:	learn: 0.8890730	test: 0.8833802	best: 0.8833802 (44)	total: 13.3s	remaining: 4m 43s
# 45:	learn: 0.8900288	test: 0.8844064	best: 0.8844064 (45)	total: 13.6s	remaining: 4m 41s
# 46:	learn: 0.8902424	test: 0.8846437	best: 0.8846437 (46)	total: 13.9s	remaining: 4m 41s
# 47:	learn: 0.8905506	test: 0.8849232	best: 0.8849232 (47)	total: 14.1s	remaining: 4m 40s
# 48:	learn: 0.8920375	test: 0.8869290	best: 0.8869290 (48)	total: 14.5s	remaining: 4m 41s
# 49:	learn: 0.8922392	test: 0.8868107	best: 0.8869290 (48)	total: 14.8s	remaining: 4m 40s
# 50:	learn: 0.8923784	test: 0.8868872	best: 0.8869290 (48)	total: 15.1s	remaining: 4m 40s
# 51:	learn: 0.8925167	test: 0.8869710	best: 0.8869710 (51)	total: 15.4s	remaining: 4m 40s
# 52:	learn: 0.8930566	test: 0.8879154	best: 0.8879154 (52)	total: 15.7s	remaining: 4m 39s
# 53:	learn: 0.8935734	test: 0.8888238	best: 0.8888238 (53)	total: 16s	remaining: 4m 40s
# 54:	learn: 0.8936691	test: 0.8886895	best: 0.8888238 (53)	total: 16.3s	remaining: 4m 39s
# 55:	learn: 0.8939877	test: 0.8891289	best: 0.8891289 (55)	total: 16.6s	remaining: 4m 40s
# 56:	learn: 0.8942347	test: 0.8893929	best: 0.8893929 (56)	total: 16.9s	remaining: 4m 40s
# 57:	learn: 0.8956159	test: 0.8912916	best: 0.8912916 (57)	total: 17.3s	remaining: 4m 40s
# 58:	learn: 0.8958287	test: 0.8917570	best: 0.8917570 (58)	total: 17.5s	remaining: 4m 39s
# 59:	learn: 0.8961393	test: 0.8921081	best: 0.8921081 (59)	total: 17.9s	remaining: 4m 40s
# 60:	learn: 0.8962051	test: 0.8920210	best: 0.8921081 (59)	total: 18.1s	remaining: 4m 39s
# 61:	learn: 0.8965211	test: 0.8924532	best: 0.8924532 (61)	total: 18.4s	remaining: 4m 38s
# 62:	learn: 0.8970043	test: 0.8930871	best: 0.8930871 (62)	total: 18.8s	remaining: 4m 40s
# 63:	learn: 0.8972106	test: 0.8931720	best: 0.8931720 (63)	total: 19.1s	remaining: 4m 38s
# 64:	learn: 0.8973500	test: 0.8932709	best: 0.8932709 (64)	total: 19.3s	remaining: 4m 37s
# 65:	learn: 0.8975001	test: 0.8932730	best: 0.8932730 (65)	total: 19.6s	remaining: 4m 37s
# 66:	learn: 0.8976696	test: 0.8935748	best: 0.8935748 (66)	total: 19.8s	remaining: 4m 36s
# 67:	learn: 0.8980059	test: 0.8941416	best: 0.8941416 (67)	total: 20.2s	remaining: 4m 36s
# 68:	learn: 0.8981860	test: 0.8942109	best: 0.8942109 (68)	total: 20.4s	remaining: 4m 35s
# 69:	learn: 0.8985063	test: 0.8947960	best: 0.8947960 (69)	total: 20.7s	remaining: 4m 35s
# 70:	learn: 0.8992394	test: 0.8954720	best: 0.8954720 (70)	total: 21.1s	remaining: 4m 36s
# 71:	learn: 0.8993819	test: 0.8955181	best: 0.8955181 (71)	total: 21.3s	remaining: 4m 35s
# 72:	learn: 0.8996221	test: 0.8958302	best: 0.8958302 (72)	total: 21.7s	remaining: 4m 35s
# 73:	learn: 0.8997433	test: 0.8958397	best: 0.8958397 (73)	total: 22.1s	remaining: 4m 35s
# 74:	learn: 0.9004797	test: 0.8962972	best: 0.8962972 (74)	total: 22.3s	remaining: 4m 34s
# 75:	learn: 0.9005907	test: 0.8963011	best: 0.8963011 (75)	total: 22.6s	remaining: 4m 35s
# 76:	learn: 0.9007540	test: 0.8963706	best: 0.8963706 (76)	total: 22.9s	remaining: 4m 34s
# 77:	learn: 0.9008289	test: 0.8965439	best: 0.8965439 (77)	total: 23.2s	remaining: 4m 34s
# 78:	learn: 0.9009529	test: 0.8967023	best: 0.8967023 (78)	total: 23.4s	remaining: 4m 32s
# 79:	learn: 0.9011384	test: 0.8967710	best: 0.8967710 (79)	total: 23.7s	remaining: 4m 32s
# 80:	learn: 0.9015667	test: 0.8974913	best: 0.8974913 (80)	total: 24s	remaining: 4m 32s
# 81:	learn: 0.9023104	test: 0.8984466	best: 0.8984466 (81)	total: 24.4s	remaining: 4m 32s
# 82:	learn: 0.9024967	test: 0.8985804	best: 0.8985804 (82)	total: 24.7s	remaining: 4m 32s
# 83:	learn: 0.9025246	test: 0.8983489	best: 0.8985804 (82)	total: 24.9s	remaining: 4m 32s
# 84:	learn: 0.9026689	test: 0.8985452	best: 0.8985804 (82)	total: 25.2s	remaining: 4m 31s
# 85:	learn: 0.9027728	test: 0.8986462	best: 0.8986462 (85)	total: 25.4s	remaining: 4m 30s
# 86:	learn: 0.9029640	test: 0.8990705	best: 0.8990705 (86)	total: 25.8s	remaining: 4m 30s
# 87:	learn: 0.9030572	test: 0.8990358	best: 0.8990705 (86)	total: 26s	remaining: 4m 29s
# 88:	learn: 0.9036282	test: 0.8998142	best: 0.8998142 (88)	total: 26.4s	remaining: 4m 29s
# 89:	learn: 0.9037302	test: 0.8998142	best: 0.8998142 (88)	total: 26.6s	remaining: 4m 29s
# 90:	learn: 0.9038390	test: 0.8998378	best: 0.8998378 (90)	total: 26.8s	remaining: 4m 28s
# 91:	learn: 0.9040285	test: 0.9002060	best: 0.9002060 (91)	total: 27.1s	remaining: 4m 27s
# 92:	learn: 0.9047004	test: 0.9008279	best: 0.9008279 (92)	total: 27.5s	remaining: 4m 28s
# 93:	learn: 0.9047348	test: 0.9008383	best: 0.9008383 (93)	total: 27.7s	remaining: 4m 27s
# 94:	learn: 0.9053819	test: 0.9017211	best: 0.9017211 (94)	total: 28s	remaining: 4m 26s
# 95:	learn: 0.9054743	test: 0.9017467	best: 0.9017467 (95)	total: 28.2s	remaining: 4m 25s
# 96:	learn: 0.9055797	test: 0.9018544	best: 0.9018544 (96)	total: 28.5s	remaining: 4m 25s
# 97:	learn: 0.9060313	test: 0.9026041	best: 0.9026041 (97)	total: 28.9s	remaining: 4m 26s
# 98:	learn: 0.9061804	test: 0.9026892	best: 0.9026892 (98)	total: 29.2s	remaining: 4m 25s
# 99:	learn: 0.9064028	test: 0.9028038	best: 0.9028038 (99)	total: 29.5s	remaining: 4m 25s
# 100:	learn: 0.9065249	test: 0.9028943	best: 0.9028943 (100)	total: 29.8s	remaining: 4m 25s
# 101:	learn: 0.9065934	test: 0.9030757	best: 0.9030757 (101)	total: 30.1s	remaining: 4m 24s
# 102:	learn: 0.9067324	test: 0.9032021	best: 0.9032021 (102)	total: 30.4s	remaining: 4m 24s
# 103:	learn: 0.9070438	test: 0.9035747	best: 0.9035747 (103)	total: 30.8s	remaining: 4m 24s
# 104:	learn: 0.9073459	test: 0.9039221	best: 0.9039221 (104)	total: 31.1s	remaining: 4m 24s
# 105:	learn: 0.9078360	test: 0.9043864	best: 0.9043864 (105)	total: 31.3s	remaining: 4m 24s
# 106:	learn: 0.9079307	test: 0.9044768	best: 0.9044768 (106)	total: 31.6s	remaining: 4m 23s
# 107:	learn: 0.9081571	test: 0.9048991	best: 0.9048991 (107)	total: 31.8s	remaining: 4m 22s
# 108:	learn: 0.9081814	test: 0.9047191	best: 0.9048991 (107)	total: 32.2s	remaining: 4m 23s
# 109:	learn: 0.9082217	test: 0.9049505	best: 0.9049505 (109)	total: 32.4s	remaining: 4m 22s
# 110:	learn: 0.9083431	test: 0.9050363	best: 0.9050363 (110)	total: 32.8s	remaining: 4m 22s
# 111:	learn: 0.9084555	test: 0.9052087	best: 0.9052087 (111)	total: 33s	remaining: 4m 21s
# 112:	learn: 0.9086694	test: 0.9054667	best: 0.9054667 (112)	total: 33.3s	remaining: 4m 21s
# 113:	learn: 0.9091452	test: 0.9060453	best: 0.9060453 (113)	total: 33.6s	remaining: 4m 21s
# 114:	learn: 0.9092886	test: 0.9062749	best: 0.9062749 (114)	total: 33.9s	remaining: 4m 20s
# 115:	learn: 0.9093767	test: 0.9063237	best: 0.9063237 (115)	total: 34.1s	remaining: 4m 19s
# 116:	learn: 0.9093838	test: 0.9062569	best: 0.9063237 (115)	total: 34.4s	remaining: 4m 19s
# 117:	learn: 0.9098206	test: 0.9069770	best: 0.9069770 (117)	total: 34.7s	remaining: 4m 19s
# 118:	learn: 0.9101087	test: 0.9073150	best: 0.9073150 (118)	total: 35.1s	remaining: 4m 19s
# 119:	learn: 0.9102017	test: 0.9074075	best: 0.9074075 (119)	total: 35.4s	remaining: 4m 19s
# 120:	learn: 0.9102596	test: 0.9074314	best: 0.9074314 (120)	total: 35.7s	remaining: 4m 19s
# 121:	learn: 0.9102975	test: 0.9075296	best: 0.9075296 (121)	total: 36.1s	remaining: 4m 19s
# 122:	learn: 0.9105299	test: 0.9078870	best: 0.9078870 (122)	total: 36.3s	remaining: 4m 18s
# 123:	learn: 0.9106503	test: 0.9080151	best: 0.9080151 (123)	total: 36.6s	remaining: 4m 18s
# 124:	learn: 0.9107094	test: 0.9080773	best: 0.9080773 (124)	total: 36.9s	remaining: 4m 18s
# 125:	learn: 0.9109681	test: 0.9083247	best: 0.9083247 (125)	total: 37.3s	remaining: 4m 18s
# 126:	learn: 0.9111185	test: 0.9085687	best: 0.9085687 (126)	total: 37.6s	remaining: 4m 18s
# 127:	learn: 0.9112082	test: 0.9085313	best: 0.9085687 (126)	total: 37.9s	remaining: 4m 18s
# 128:	learn: 0.9113205	test: 0.9085121	best: 0.9085687 (126)	total: 38.1s	remaining: 4m 17s
# 129:	learn: 0.9113846	test: 0.9084864	best: 0.9085687 (126)	total: 38.4s	remaining: 4m 17s
# 130:	learn: 0.9115855	test: 0.9088098	best: 0.9088098 (130)	total: 38.7s	remaining: 4m 16s
# 131:	learn: 0.9117844	test: 0.9089051	best: 0.9089051 (131)	total: 39s	remaining: 4m 16s
# 132:	learn: 0.9118380	test: 0.9089111	best: 0.9089111 (132)	total: 39.2s	remaining: 4m 15s
# 133:	learn: 0.9120112	test: 0.9089197	best: 0.9089197 (133)	total: 39.5s	remaining: 4m 15s
# 134:	learn: 0.9122254	test: 0.9093705	best: 0.9093705 (134)	total: 39.8s	remaining: 4m 15s
# 135:	learn: 0.9123357	test: 0.9094910	best: 0.9094910 (135)	total: 40.1s	remaining: 4m 14s
# 136:	learn: 0.9124299	test: 0.9095216	best: 0.9095216 (136)	total: 40.4s	remaining: 4m 14s
# 137:	learn: 0.9125228	test: 0.9096324	best: 0.9096324 (137)	total: 40.7s	remaining: 4m 14s
# 138:	learn: 0.9125855	test: 0.9096108	best: 0.9096324 (137)	total: 41.1s	remaining: 4m 14s
# 139:	learn: 0.9127072	test: 0.9097524	best: 0.9097524 (139)	total: 41.5s	remaining: 4m 14s
# 140:	learn: 0.9127593	test: 0.9097637	best: 0.9097637 (140)	total: 41.8s	remaining: 4m 14s
# 141:	learn: 0.9128341	test: 0.9098230	best: 0.9098230 (141)	total: 42.1s	remaining: 4m 14s
# 142:	learn: 0.9129801	test: 0.9132952	best: 0.9132952 (142)	total: 42.5s	remaining: 4m 14s
# 143:	learn: 0.9130006	test: 0.9132518	best: 0.9132952 (142)	total: 42.9s	remaining: 4m 14s
# 144:	learn: 0.9130082	test: 0.9132778	best: 0.9132952 (142)	total: 43.1s	remaining: 4m 14s
# 145:	learn: 0.9131131	test: 0.9134175	best: 0.9134175 (145)	total: 43.5s	remaining: 4m 14s
# 146:	learn: 0.9132043	test: 0.9135265	best: 0.9135265 (146)	total: 43.8s	remaining: 4m 14s
# 147:	learn: 0.9132334	test: 0.9135924	best: 0.9135924 (147)	total: 44.1s	remaining: 4m 14s
# 148:	learn: 0.9134115	test: 0.9136101	best: 0.9136101 (148)	total: 44.4s	remaining: 4m 13s
# 149:	learn: 0.9135340	test: 0.9136647	best: 0.9136647 (149)	total: 44.7s	remaining: 4m 13s
# 150:	learn: 0.9136103	test: 0.9137653	best: 0.9137653 (150)	total: 45s	remaining: 4m 12s
# 151:	learn: 0.9136816	test: 0.9139473	best: 0.9139473 (151)	total: 45.3s	remaining: 4m 12s
# 152:	learn: 0.9137130	test: 0.9140110	best: 0.9140110 (152)	total: 45.5s	remaining: 4m 12s
# 153:	learn: 0.9138268	test: 0.9142000	best: 0.9142000 (153)	total: 45.8s	remaining: 4m 11s
# 154:	learn: 0.9138825	test: 0.9142088	best: 0.9142088 (154)	total: 46.1s	remaining: 4m 11s
# 155:	learn: 0.9140766	test: 0.9144153	best: 0.9144153 (155)	total: 46.3s	remaining: 4m 10s
# 156:	learn: 0.9141056	test: 0.9143290	best: 0.9144153 (155)	total: 46.7s	remaining: 4m 10s
# 157:	learn: 0.9141747	test: 0.9144318	best: 0.9144318 (157)	total: 47s	remaining: 4m 10s
# 158:	learn: 0.9142300	test: 0.9144399	best: 0.9144399 (158)	total: 47.3s	remaining: 4m 9s
# 159:	learn: 0.9144079	test: 0.9146728	best: 0.9146728 (159)	total: 47.6s	remaining: 4m 9s
# 160:	learn: 0.9144411	test: 0.9147255	best: 0.9147255 (160)	total: 47.8s	remaining: 4m 9s
# 161:	learn: 0.9145161	test: 0.9147175	best: 0.9147255 (160)	total: 48.2s	remaining: 4m 9s
# 162:	learn: 0.9145616	test: 0.9147763	best: 0.9147763 (162)	total: 48.4s	remaining: 4m 8s
# 163:	learn: 0.9146947	test: 0.9149204	best: 0.9149204 (163)	total: 48.8s	remaining: 4m 8s
# 164:	learn: 0.9147249	test: 0.9149709	best: 0.9149709 (164)	total: 49s	remaining: 4m 8s
# 165:	learn: 0.9147729	test: 0.9149798	best: 0.9149798 (165)	total: 49.3s	remaining: 4m 7s
# 166:	learn: 0.9149136	test: 0.9152099	best: 0.9152099 (166)	total: 49.6s	remaining: 4m 7s
# 167:	learn: 0.9149934	test: 0.9152021	best: 0.9152099 (166)	total: 49.9s	remaining: 4m 7s
# 168:	learn: 0.9150517	test: 0.9152163	best: 0.9152163 (168)	total: 50.2s	remaining: 4m 6s
# 169:	learn: 0.9151230	test: 0.9151648	best: 0.9152163 (168)	total: 50.5s	remaining: 4m 6s
# 170:	learn: 0.9152163	test: 0.9153709	best: 0.9153709 (170)	total: 50.8s	remaining: 4m 6s
# 171:	learn: 0.9152536	test: 0.9153749	best: 0.9153749 (171)	total: 51.2s	remaining: 4m 6s
# 172:	learn: 0.9153181	test: 0.9155317	best: 0.9155317 (172)	total: 51.5s	remaining: 4m 6s
# 173:	learn: 0.9154557	test: 0.9156687	best: 0.9156687 (173)	total: 51.8s	remaining: 4m 6s
# 174:	learn: 0.9155430	test: 0.9157304	best: 0.9157304 (174)	total: 52.1s	remaining: 4m 5s
# 175:	learn: 0.9156178	test: 0.9158012	best: 0.9158012 (175)	total: 52.4s	remaining: 4m 5s
# 176:	learn: 0.9156847	test: 0.9158727	best: 0.9158727 (176)	total: 52.7s	remaining: 4m 5s
# 177:	learn: 0.9157634	test: 0.9159015	best: 0.9159015 (177)	total: 53s	remaining: 4m 4s
# 178:	learn: 0.9158988	test: 0.9159483	best: 0.9159483 (178)	total: 53.3s	remaining: 4m 4s
# 179:	learn: 0.9159328	test: 0.9159075	best: 0.9159483 (178)	total: 53.6s	remaining: 4m 3s
# 180:	learn: 0.9160021	test: 0.9160422	best: 0.9160422 (180)	total: 53.8s	remaining: 4m 3s
# 181:	learn: 0.9160449	test: 0.9160720	best: 0.9160720 (181)	total: 54.2s	remaining: 4m 3s
# 182:	learn: 0.9162643	test: 0.9162095	best: 0.9162095 (182)	total: 54.5s	remaining: 4m 3s
# 183:	learn: 0.9162889	test: 0.9162126	best: 0.9162126 (183)	total: 54.8s	remaining: 4m 2s
# 184:	learn: 0.9163303	test: 0.9162841	best: 0.9162841 (184)	total: 55s	remaining: 4m 2s
# 185:	learn: 0.9163781	test: 0.9162946	best: 0.9162946 (185)	total: 55.2s	remaining: 4m 1s
# 186:	learn: 0.9165036	test: 0.9165094	best: 0.9165094 (186)	total: 55.6s	remaining: 4m 1s
# 187:	learn: 0.9165483	test: 0.9164939	best: 0.9165094 (186)	total: 55.9s	remaining: 4m 1s
# 188:	learn: 0.9165678	test: 0.9164964	best: 0.9165094 (186)	total: 56.2s	remaining: 4m 1s
# 189:	learn: 0.9165792	test: 0.9166182	best: 0.9166182 (189)	total: 56.6s	remaining: 4m 1s
# 190:	learn: 0.9166146	test: 0.9165817	best: 0.9166182 (189)	total: 56.9s	remaining: 4m
# 191:	learn: 0.9166387	test: 0.9165082	best: 0.9166182 (189)	total: 57.2s	remaining: 4m
# 192:	learn: 0.9167097	test: 0.9165478	best: 0.9166182 (189)	total: 57.5s	remaining: 4m
# 193:	learn: 0.9167546	test: 0.9165131	best: 0.9166182 (189)	total: 57.8s	remaining: 4m
# 194:	learn: 0.9168563	test: 0.9165239	best: 0.9166182 (189)	total: 58.1s	remaining: 3m 59s
# 195:	learn: 0.9169233	test: 0.9164512	best: 0.9166182 (189)	total: 58.3s	remaining: 3m 59s
# 196:	learn: 0.9170175	test: 0.9164150	best: 0.9166182 (189)	total: 58.6s	remaining: 3m 58s
# 197:	learn: 0.9170248	test: 0.9164881	best: 0.9166182 (189)	total: 58.8s	remaining: 3m 58s
# 198:	learn: 0.9170656	test: 0.9165841	best: 0.9166182 (189)	total: 59.1s	remaining: 3m 57s
# 199:	learn: 0.9171401	test: 0.9168146	best: 0.9168146 (199)	total: 59.5s	remaining: 3m 57s
# 200:	learn: 0.9171325	test: 0.9168386	best: 0.9168386 (200)	total: 59.9s	remaining: 3m 57s
# 201:	learn: 0.9172033	test: 0.9170143	best: 0.9170143 (201)	total: 1m	remaining: 3m 57s
# 202:	learn: 0.9172611	test: 0.9170087	best: 0.9170143 (201)	total: 1m	remaining: 3m 57s
# 203:	learn: 0.9173271	test: 0.9172191	best: 0.9172191 (203)	total: 1m	remaining: 3m 57s
# 204:	learn: 0.9174651	test: 0.9173897	best: 0.9173897 (204)	total: 1m 1s	remaining: 3m 57s
# 205:	learn: 0.9174700	test: 0.9173895	best: 0.9173897 (204)	total: 1m 1s	remaining: 3m 56s
# 206:	learn: 0.9175015	test: 0.9174967	best: 0.9174967 (206)	total: 1m 1s	remaining: 3m 56s
# 207:	learn: 0.9175770	test: 0.9175061	best: 0.9175061 (207)	total: 1m 2s	remaining: 3m 56s
# 208:	learn: 0.9176151	test: 0.9175316	best: 0.9175316 (208)	total: 1m 2s	remaining: 3m 56s
# 209:	learn: 0.9176315	test: 0.9174569	best: 0.9175316 (208)	total: 1m 2s	remaining: 3m 56s
# 210:	learn: 0.9176853	test: 0.9175306	best: 0.9175316 (208)	total: 1m 3s	remaining: 3m 55s
# 211:	learn: 0.9177941	test: 0.9175288	best: 0.9175316 (208)	total: 1m 3s	remaining: 3m 55s
# 212:	learn: 0.9178481	test: 0.9175297	best: 0.9175316 (208)	total: 1m 3s	remaining: 3m 55s
# 213:	learn: 0.9179063	test: 0.9175760	best: 0.9175760 (213)	total: 1m 3s	remaining: 3m 54s
# 214:	learn: 0.9179571	test: 0.9175587	best: 0.9175760 (213)	total: 1m 4s	remaining: 3m 54s
# 215:	learn: 0.9179855	test: 0.9175708	best: 0.9175760 (213)	total: 1m 4s	remaining: 3m 54s
# 216:	learn: 0.9180112	test: 0.9176285	best: 0.9176285 (216)	total: 1m 4s	remaining: 3m 54s
# 217:	learn: 0.9180052	test: 0.9176327	best: 0.9176327 (217)	total: 1m 5s	remaining: 3m 53s
# 218:	learn: 0.9180475	test: 0.9175828	best: 0.9176327 (217)	total: 1m 5s	remaining: 3m 53s
# 219:	learn: 0.9181070	test: 0.9176871	best: 0.9176871 (219)	total: 1m 5s	remaining: 3m 53s
# 220:	learn: 0.9181138	test: 0.9175874	best: 0.9176871 (219)	total: 1m 6s	remaining: 3m 53s
# 221:	learn: 0.9181370	test: 0.9176786	best: 0.9176871 (219)	total: 1m 6s	remaining: 3m 52s
# 222:	learn: 0.9181463	test: 0.9177379	best: 0.9177379 (222)	total: 1m 6s	remaining: 3m 52s
# 223:	learn: 0.9182224	test: 0.9178543	best: 0.9178543 (223)	total: 1m 7s	remaining: 3m 52s
# 224:	learn: 0.9182682	test: 0.9177512	best: 0.9178543 (223)	total: 1m 7s	remaining: 3m 52s
# 225:	learn: 0.9182964	test: 0.9177318	best: 0.9178543 (223)	total: 1m 7s	remaining: 3m 51s
# 226:	learn: 0.9183153	test: 0.9177965	best: 0.9178543 (223)	total: 1m 7s	remaining: 3m 51s
# 227:	learn: 0.9184150	test: 0.9178434	best: 0.9178543 (223)	total: 1m 8s	remaining: 3m 51s
# 228:	learn: 0.9184277	test: 0.9178086	best: 0.9178543 (223)	total: 1m 8s	remaining: 3m 51s
# 229:	learn: 0.9184583	test: 0.9177701	best: 0.9178543 (223)	total: 1m 8s	remaining: 3m 50s
# 230:	learn: 0.9184441	test: 0.9177751	best: 0.9178543 (223)	total: 1m 9s	remaining: 3m 50s
# 231:	learn: 0.9184796	test: 0.9177605	best: 0.9178543 (223)	total: 1m 9s	remaining: 3m 50s
# 232:	learn: 0.9185340	test: 0.9178249	best: 0.9178543 (223)	total: 1m 9s	remaining: 3m 50s
# 233:	learn: 0.9185860	test: 0.9178421	best: 0.9178543 (223)	total: 1m 10s	remaining: 3m 49s
# 234:	learn: 0.9186404	test: 0.9178516	best: 0.9178543 (223)	total: 1m 10s	remaining: 3m 49s
# 235:	learn: 0.9186973	test: 0.9178281	best: 0.9178543 (223)	total: 1m 10s	remaining: 3m 49s
# 236:	learn: 0.9186713	test: 0.9178052	best: 0.9178543 (223)	total: 1m 11s	remaining: 3m 48s
# 237:	learn: 0.9187588	test: 0.9177313	best: 0.9178543 (223)	total: 1m 11s	remaining: 3m 48s
# 238:	learn: 0.9187827	test: 0.9178260	best: 0.9178543 (223)	total: 1m 11s	remaining: 3m 48s
# 239:	learn: 0.9187974	test: 0.9178286	best: 0.9178543 (223)	total: 1m 11s	remaining: 3m 47s
# 240:	learn: 0.9189997	test: 0.9180319	best: 0.9180319 (240)	total: 1m 12s	remaining: 3m 47s
# 241:	learn: 0.9190633	test: 0.9181478	best: 0.9181478 (241)	total: 1m 12s	remaining: 3m 47s
# 242:	learn: 0.9190933	test: 0.9181678	best: 0.9181678 (242)	total: 1m 12s	remaining: 3m 47s
# 243:	learn: 0.9191107	test: 0.9181998	best: 0.9181998 (243)	total: 1m 13s	remaining: 3m 46s
# 244:	learn: 0.9191753	test: 0.9182469	best: 0.9182469 (244)	total: 1m 13s	remaining: 3m 46s
# 245:	learn: 0.9192037	test: 0.9183467	best: 0.9183467 (245)	total: 1m 13s	remaining: 3m 46s
# 246:	learn: 0.9192282	test: 0.9183501	best: 0.9183501 (246)	total: 1m 14s	remaining: 3m 46s
# 247:	learn: 0.9192906	test: 0.9183510	best: 0.9183510 (247)	total: 1m 14s	remaining: 3m 46s
# 248:	learn: 0.9193180	test: 0.9183780	best: 0.9183780 (248)	total: 1m 14s	remaining: 3m 45s
# 249:	learn: 0.9193360	test: 0.9183437	best: 0.9183780 (248)	total: 1m 15s	remaining: 3m 45s
# 250:	learn: 0.9193684	test: 0.9183741	best: 0.9183780 (248)	total: 1m 15s	remaining: 3m 44s
# 251:	learn: 0.9193775	test: 0.9184763	best: 0.9184763 (251)	total: 1m 15s	remaining: 3m 44s
# 252:	learn: 0.9194045	test: 0.9184799	best: 0.9184799 (252)	total: 1m 15s	remaining: 3m 44s
# 253:	learn: 0.9194356	test: 0.9184931	best: 0.9184931 (253)	total: 1m 16s	remaining: 3m 43s
# 254:	learn: 0.9194596	test: 0.9185455	best: 0.9185455 (254)	total: 1m 16s	remaining: 3m 43s
# 255:	learn: 0.9194633	test: 0.9184777	best: 0.9185455 (254)	total: 1m 16s	remaining: 3m 43s
# 256:	learn: 0.9195028	test: 0.9185002	best: 0.9185455 (254)	total: 1m 17s	remaining: 3m 43s
# 257:	learn: 0.9195276	test: 0.9185213	best: 0.9185455 (254)	total: 1m 17s	remaining: 3m 42s
# 258:	learn: 0.9195905	test: 0.9185180	best: 0.9185455 (254)	total: 1m 17s	remaining: 3m 42s
# 259:	learn: 0.9195830	test: 0.9186229	best: 0.9186229 (259)	total: 1m 18s	remaining: 3m 42s
# 260:	learn: 0.9196420	test: 0.9186063	best: 0.9186229 (259)	total: 1m 18s	remaining: 3m 41s
# 261:	learn: 0.9196575	test: 0.9186218	best: 0.9186229 (259)	total: 1m 18s	remaining: 3m 41s
# 262:	learn: 0.9196902	test: 0.9185675	best: 0.9186229 (259)	total: 1m 18s	remaining: 3m 41s
# 263:	learn: 0.9197161	test: 0.9185806	best: 0.9186229 (259)	total: 1m 19s	remaining: 3m 40s
# 264:	learn: 0.9197825	test: 0.9186399	best: 0.9186399 (264)	total: 1m 19s	remaining: 3m 40s
# 265:	learn: 0.9197805	test: 0.9186491	best: 0.9186491 (265)	total: 1m 19s	remaining: 3m 40s
# 266:	learn: 0.9198383	test: 0.9187272	best: 0.9187272 (266)	total: 1m 20s	remaining: 3m 39s
# 267:	learn: 0.9198773	test: 0.9188251	best: 0.9188251 (267)	total: 1m 20s	remaining: 3m 39s
# 268:	learn: 0.9199332	test: 0.9189051	best: 0.9189051 (268)	total: 1m 20s	remaining: 3m 39s
# 269:	learn: 0.9199430	test: 0.9188970	best: 0.9189051 (268)	total: 1m 21s	remaining: 3m 39s
# 270:	learn: 0.9199510	test: 0.9188918	best: 0.9189051 (268)	total: 1m 21s	remaining: 3m 38s
# 271:	learn: 0.9199885	test: 0.9189164	best: 0.9189164 (271)	total: 1m 21s	remaining: 3m 38s
# 272:	learn: 0.9200679	test: 0.9189717	best: 0.9189717 (272)	total: 1m 21s	remaining: 3m 38s
# 273:	learn: 0.9201555	test: 0.9190728	best: 0.9190728 (273)	total: 1m 22s	remaining: 3m 38s
# 274:	learn: 0.9202282	test: 0.9190048	best: 0.9190728 (273)	total: 1m 22s	remaining: 3m 37s
# 275:	learn: 0.9202817	test: 0.9189731	best: 0.9190728 (273)	total: 1m 22s	remaining: 3m 37s
# 276:	learn: 0.9202997	test: 0.9189609	best: 0.9190728 (273)	total: 1m 23s	remaining: 3m 36s
# 277:	learn: 0.9202963	test: 0.9189289	best: 0.9190728 (273)	total: 1m 23s	remaining: 3m 36s
# 278:	learn: 0.9203366	test: 0.9189927	best: 0.9190728 (273)	total: 1m 23s	remaining: 3m 36s
# 279:	learn: 0.9203956	test: 0.9190139	best: 0.9190728 (273)	total: 1m 23s	remaining: 3m 35s
# 280:	learn: 0.9205022	test: 0.9189658	best: 0.9190728 (273)	total: 1m 24s	remaining: 3m 35s
# 281:	learn: 0.9205091	test: 0.9190114	best: 0.9190728 (273)	total: 1m 24s	remaining: 3m 35s
# 282:	learn: 0.9205088	test: 0.9190382	best: 0.9190728 (273)	total: 1m 24s	remaining: 3m 35s
# 283:	learn: 0.9205199	test: 0.9190429	best: 0.9190728 (273)	total: 1m 25s	remaining: 3m 34s
# 284:	learn: 0.9205607	test: 0.9190773	best: 0.9190773 (284)	total: 1m 25s	remaining: 3m 34s
# 285:	learn: 0.9205842	test: 0.9191258	best: 0.9191258 (285)	total: 1m 25s	remaining: 3m 34s
# 286:	learn: 0.9206149	test: 0.9191644	best: 0.9191644 (286)	total: 1m 26s	remaining: 3m 33s
# 287:	learn: 0.9206522	test: 0.9191881	best: 0.9191881 (287)	total: 1m 26s	remaining: 3m 33s
# 288:	learn: 0.9206562	test: 0.9192066	best: 0.9192066 (288)	total: 1m 26s	remaining: 3m 33s
# 289:	learn: 0.9207170	test: 0.9192121	best: 0.9192121 (289)	total: 1m 27s	remaining: 3m 33s
# 290:	learn: 0.9207402	test: 0.9191953	best: 0.9192121 (289)	total: 1m 27s	remaining: 3m 32s
# 291:	learn: 0.9207678	test: 0.9191280	best: 0.9192121 (289)	total: 1m 27s	remaining: 3m 32s
# 292:	learn: 0.9207687	test: 0.9191008	best: 0.9192121 (289)	total: 1m 28s	remaining: 3m 32s
# 293:	learn: 0.9207570	test: 0.9191560	best: 0.9192121 (289)	total: 1m 28s	remaining: 3m 31s
# 294:	learn: 0.9208215	test: 0.9193239	best: 0.9193239 (294)	total: 1m 28s	remaining: 3m 31s
# 295:	learn: 0.9208500	test: 0.9193600	best: 0.9193600 (295)	total: 1m 28s	remaining: 3m 31s
# 296:	learn: 0.9208608	test: 0.9193558	best: 0.9193600 (295)	total: 1m 29s	remaining: 3m 31s
# 297:	learn: 0.9209182	test: 0.9194599	best: 0.9194599 (297)	total: 1m 29s	remaining: 3m 31s
# 298:	learn: 0.9209452	test: 0.9194181	best: 0.9194599 (297)	total: 1m 29s	remaining: 3m 30s
# 299:	learn: 0.9209601	test: 0.9195381	best: 0.9195381 (299)	total: 1m 30s	remaining: 3m 30s
# 300:	learn: 0.9209779	test: 0.9195730	best: 0.9195730 (300)	total: 1m 30s	remaining: 3m 30s
# 301:	learn: 0.9209938	test: 0.9196679	best: 0.9196679 (301)	total: 1m 30s	remaining: 3m 29s
# 302:	learn: 0.9210200	test: 0.9195660	best: 0.9196679 (301)	total: 1m 30s	remaining: 3m 29s
# 303:	learn: 0.9210677	test: 0.9195873	best: 0.9196679 (301)	total: 1m 31s	remaining: 3m 29s
# 304:	learn: 0.9211129	test: 0.9195805	best: 0.9196679 (301)	total: 1m 31s	remaining: 3m 28s
# 305:	learn: 0.9211451	test: 0.9195401	best: 0.9196679 (301)	total: 1m 31s	remaining: 3m 28s
# 306:	learn: 0.9212424	test: 0.9194545	best: 0.9196679 (301)	total: 1m 32s	remaining: 3m 28s
# 307:	learn: 0.9212576	test: 0.9195080	best: 0.9196679 (301)	total: 1m 32s	remaining: 3m 28s
# 308:	learn: 0.9212791	test: 0.9195538	best: 0.9196679 (301)	total: 1m 32s	remaining: 3m 27s
# 309:	learn: 0.9212851	test: 0.9195605	best: 0.9196679 (301)	total: 1m 33s	remaining: 3m 27s
# 310:	learn: 0.9212920	test: 0.9195774	best: 0.9196679 (301)	total: 1m 33s	remaining: 3m 27s
# 311:	learn: 0.9212982	test: 0.9195487	best: 0.9196679 (301)	total: 1m 33s	remaining: 3m 26s
# 312:	learn: 0.9213700	test: 0.9195621	best: 0.9196679 (301)	total: 1m 34s	remaining: 3m 26s
# 313:	learn: 0.9213925	test: 0.9195973	best: 0.9196679 (301)	total: 1m 34s	remaining: 3m 26s
# 314:	learn: 0.9214292	test: 0.9195996	best: 0.9196679 (301)	total: 1m 34s	remaining: 3m 26s
# 315:	learn: 0.9214421	test: 0.9196044	best: 0.9196679 (301)	total: 1m 35s	remaining: 3m 25s
# 316:	learn: 0.9215482	test: 0.9197078	best: 0.9197078 (316)	total: 1m 35s	remaining: 3m 25s
# 317:	learn: 0.9215783	test: 0.9196889	best: 0.9197078 (316)	total: 1m 35s	remaining: 3m 25s
# 318:	learn: 0.9215638	test: 0.9197237	best: 0.9197237 (318)	total: 1m 36s	remaining: 3m 25s
# 319:	learn: 0.9215872	test: 0.9197507	best: 0.9197507 (319)	total: 1m 36s	remaining: 3m 25s
# 320:	learn: 0.9216427	test: 0.9197125	best: 0.9197507 (319)	total: 1m 36s	remaining: 3m 24s
# 321:	learn: 0.9216406	test: 0.9197372	best: 0.9197507 (319)	total: 1m 37s	remaining: 3m 24s
# 322:	learn: 0.9216964	test: 0.9197056	best: 0.9197507 (319)	total: 1m 37s	remaining: 3m 24s
# 323:	learn: 0.9217161	test: 0.9197418	best: 0.9197507 (319)	total: 1m 37s	remaining: 3m 23s
# 324:	learn: 0.9217253	test: 0.9197288	best: 0.9197507 (319)	total: 1m 38s	remaining: 3m 23s
# 325:	learn: 0.9217231	test: 0.9197083	best: 0.9197507 (319)	total: 1m 38s	remaining: 3m 23s
# 326:	learn: 0.9217494	test: 0.9197557	best: 0.9197557 (326)	total: 1m 38s	remaining: 3m 23s
# 327:	learn: 0.9217745	test: 0.9197925	best: 0.9197925 (327)	total: 1m 39s	remaining: 3m 22s
# 328:	learn: 0.9217837	test: 0.9198036	best: 0.9198036 (328)	total: 1m 39s	remaining: 3m 22s
# 329:	learn: 0.9218074	test: 0.9198080	best: 0.9198080 (329)	total: 1m 39s	remaining: 3m 22s
# 330:	learn: 0.9218449	test: 0.9198800	best: 0.9198800 (330)	total: 1m 39s	remaining: 3m 21s
# 331:	learn: 0.9218452	test: 0.9199389	best: 0.9199389 (331)	total: 1m 40s	remaining: 3m 21s
# 332:	learn: 0.9218441	test: 0.9199488	best: 0.9199488 (332)	total: 1m 40s	remaining: 3m 21s
# 333:	learn: 0.9218745	test: 0.9199178	best: 0.9199488 (332)	total: 1m 40s	remaining: 3m 20s
# 334:	learn: 0.9218785	test: 0.9199055	best: 0.9199488 (332)	total: 1m 41s	remaining: 3m 20s
# 335:	learn: 0.9219400	test: 0.9199134	best: 0.9199488 (332)	total: 1m 41s	remaining: 3m 20s
# 336:	learn: 0.9219505	test: 0.9198999	best: 0.9199488 (332)	total: 1m 41s	remaining: 3m 20s
# 337:	learn: 0.9219543	test: 0.9199695	best: 0.9199695 (337)	total: 1m 41s	remaining: 3m 19s
# 338:	learn: 0.9220134	test: 0.9200577	best: 0.9200577 (338)	total: 1m 42s	remaining: 3m 19s
# 339:	learn: 0.9220439	test: 0.9200653	best: 0.9200653 (339)	total: 1m 42s	remaining: 3m 18s
# 340:	learn: 0.9220356	test: 0.9200781	best: 0.9200781 (340)	total: 1m 42s	remaining: 3m 18s
# 341:	learn: 0.9220593	test: 0.9200666	best: 0.9200781 (340)	total: 1m 43s	remaining: 3m 18s
# 342:	learn: 0.9220876	test: 0.9200580	best: 0.9200781 (340)	total: 1m 43s	remaining: 3m 18s
# 343:	learn: 0.9221118	test: 0.9201112	best: 0.9201112 (343)	total: 1m 43s	remaining: 3m 17s
# 344:	learn: 0.9220967	test: 0.9201999	best: 0.9201999 (344)	total: 1m 44s	remaining: 3m 17s
# 345:	learn: 0.9221126	test: 0.9201461	best: 0.9201999 (344)	total: 1m 44s	remaining: 3m 17s
# 346:	learn: 0.9221128	test: 0.9201600	best: 0.9201999 (344)	total: 1m 44s	remaining: 3m 16s
# 347:	learn: 0.9221474	test: 0.9202296	best: 0.9202296 (347)	total: 1m 44s	remaining: 3m 16s
# 348:	learn: 0.9221591	test: 0.9202215	best: 0.9202296 (347)	total: 1m 45s	remaining: 3m 15s
# 349:	learn: 0.9221984	test: 0.9203047	best: 0.9203047 (349)	total: 1m 45s	remaining: 3m 15s
# 350:	learn: 0.9222180	test: 0.9203052	best: 0.9203052 (350)	total: 1m 45s	remaining: 3m 15s
# 351:	learn: 0.9222060	test: 0.9202911	best: 0.9203052 (350)	total: 1m 45s	remaining: 3m 15s
# 352:	learn: 0.9222294	test: 0.9203144	best: 0.9203144 (352)	total: 1m 46s	remaining: 3m 14s
# 353:	learn: 0.9222740	test: 0.9204156	best: 0.9204156 (353)	total: 1m 46s	remaining: 3m 14s
# 354:	learn: 0.9222847	test: 0.9205017	best: 0.9205017 (354)	total: 1m 47s	remaining: 3m 14s
# 355:	learn: 0.9223044	test: 0.9204974	best: 0.9205017 (354)	total: 1m 47s	remaining: 3m 14s
# 356:	learn: 0.9223454	test: 0.9205648	best: 0.9205648 (356)	total: 1m 47s	remaining: 3m 13s
# 357:	learn: 0.9223942	test: 0.9204536	best: 0.9205648 (356)	total: 1m 47s	remaining: 3m 13s
# 358:	learn: 0.9223945	test: 0.9204535	best: 0.9205648 (356)	total: 1m 48s	remaining: 3m 13s
# 359:	learn: 0.9224347	test: 0.9204374	best: 0.9205648 (356)	total: 1m 48s	remaining: 3m 13s
# 360:	learn: 0.9224632	test: 0.9204856	best: 0.9205648 (356)	total: 1m 49s	remaining: 3m 13s
# 361:	learn: 0.9224789	test: 0.9204888	best: 0.9205648 (356)	total: 1m 49s	remaining: 3m 12s
# 362:	learn: 0.9224697	test: 0.9204803	best: 0.9205648 (356)	total: 1m 49s	remaining: 3m 12s
# 363:	learn: 0.9224920	test: 0.9204473	best: 0.9205648 (356)	total: 1m 50s	remaining: 3m 12s
# 364:	learn: 0.9225538	test: 0.9204638	best: 0.9205648 (356)	total: 1m 50s	remaining: 3m 12s
# 365:	learn: 0.9225973	test: 0.9204789	best: 0.9205648 (356)	total: 1m 50s	remaining: 3m 11s
# 366:	learn: 0.9227146	test: 0.9206653	best: 0.9206653 (366)	total: 1m 50s	remaining: 3m 11s
# 367:	learn: 0.9227394	test: 0.9206776	best: 0.9206776 (367)	total: 1m 51s	remaining: 3m 11s
# 368:	learn: 0.9227584	test: 0.9207192	best: 0.9207192 (368)	total: 1m 51s	remaining: 3m 10s
# 369:	learn: 0.9227713	test: 0.9207136	best: 0.9207192 (368)	total: 1m 51s	remaining: 3m 10s
# 370:	learn: 0.9227808	test: 0.9206305	best: 0.9207192 (368)	total: 1m 52s	remaining: 3m 10s
# 371:	learn: 0.9228062	test: 0.9206286	best: 0.9207192 (368)	total: 1m 52s	remaining: 3m 9s
# 372:	learn: 0.9228173	test: 0.9206434	best: 0.9207192 (368)	total: 1m 52s	remaining: 3m 9s
# 373:	learn: 0.9228307	test: 0.9206590	best: 0.9207192 (368)	total: 1m 53s	remaining: 3m 9s
# 374:	learn: 0.9228669	test: 0.9206735	best: 0.9207192 (368)	total: 1m 53s	remaining: 3m 8s
# 375:	learn: 0.9228912	test: 0.9206604	best: 0.9207192 (368)	total: 1m 53s	remaining: 3m 8s
# 376:	learn: 0.9228860	test: 0.9206438	best: 0.9207192 (368)	total: 1m 53s	remaining: 3m 8s
# 377:	learn: 0.9229828	test: 0.9207138	best: 0.9207192 (368)	total: 1m 54s	remaining: 3m 8s
# 378:	learn: 0.9230139	test: 0.9206882	best: 0.9207192 (368)	total: 1m 54s	remaining: 3m 7s
# 379:	learn: 0.9230470	test: 0.9206805	best: 0.9207192 (368)	total: 1m 54s	remaining: 3m 7s
# 380:	learn: 0.9230794	test: 0.9207191	best: 0.9207192 (368)	total: 1m 55s	remaining: 3m 7s
# 381:	learn: 0.9231127	test: 0.9206869	best: 0.9207192 (368)	total: 1m 55s	remaining: 3m 6s
# 382:	learn: 0.9231121	test: 0.9207254	best: 0.9207254 (382)	total: 1m 55s	remaining: 3m 6s
# 383:	learn: 0.9231380	test: 0.9206575	best: 0.9207254 (382)	total: 1m 56s	remaining: 3m 6s
# 384:	learn: 0.9231590	test: 0.9206870	best: 0.9207254 (382)	total: 1m 56s	remaining: 3m 5s
# 385:	learn: 0.9231661	test: 0.9206608	best: 0.9207254 (382)	total: 1m 56s	remaining: 3m 5s
# 386:	learn: 0.9232226	test: 0.9206764	best: 0.9207254 (382)	total: 1m 57s	remaining: 3m 5s
# 387:	learn: 0.9232348	test: 0.9207356	best: 0.9207356 (387)	total: 1m 57s	remaining: 3m 5s
# 388:	learn: 0.9232688	test: 0.9206228	best: 0.9207356 (387)	total: 1m 57s	remaining: 3m 4s
# 389:	learn: 0.9232820	test: 0.9206555	best: 0.9207356 (387)	total: 1m 58s	remaining: 3m 4s
# 390:	learn: 0.9233172	test: 0.9206601	best: 0.9207356 (387)	total: 1m 58s	remaining: 3m 4s
# 391:	learn: 0.9233280	test: 0.9207335	best: 0.9207356 (387)	total: 1m 58s	remaining: 3m 4s
# 392:	learn: 0.9233370	test: 0.9207284	best: 0.9207356 (387)	total: 1m 59s	remaining: 3m 3s
# 393:	learn: 0.9233186	test: 0.9207514	best: 0.9207514 (393)	total: 1m 59s	remaining: 3m 3s
# 394:	learn: 0.9233622	test: 0.9208142	best: 0.9208142 (394)	total: 1m 59s	remaining: 3m 3s
# 395:	learn: 0.9233946	test: 0.9208355	best: 0.9208355 (395)	total: 1m 59s	remaining: 3m 3s
# 396:	learn: 0.9234157	test: 0.9209730	best: 0.9209730 (396)	total: 2m	remaining: 3m 2s
# 397:	learn: 0.9234963	test: 0.9208568	best: 0.9209730 (396)	total: 2m	remaining: 3m 2s
# 398:	learn: 0.9234943	test: 0.9209014	best: 0.9209730 (396)	total: 2m 1s	remaining: 3m 2s
# 399:	learn: 0.9235668	test: 0.9209503	best: 0.9209730 (396)	total: 2m 1s	remaining: 3m 2s
# 400:	learn: 0.9235807	test: 0.9209475	best: 0.9209730 (396)	total: 2m 1s	remaining: 3m 1s
# 401:	learn: 0.9235988	test: 0.9209303	best: 0.9209730 (396)	total: 2m 1s	remaining: 3m 1s
# 402:	learn: 0.9236205	test: 0.9209149	best: 0.9209730 (396)	total: 2m 2s	remaining: 3m 1s
# 403:	learn: 0.9236683	test: 0.9208806	best: 0.9209730 (396)	total: 2m 2s	remaining: 3m
# 404:	learn: 0.9236496	test: 0.9208964	best: 0.9209730 (396)	total: 2m 2s	remaining: 3m
# 405:	learn: 0.9236822	test: 0.9208802	best: 0.9209730 (396)	total: 2m 3s	remaining: 3m
# 406:	learn: 0.9236829	test: 0.9209756	best: 0.9209756 (406)	total: 2m 3s	remaining: 2m 59s
# 407:	learn: 0.9236957	test: 0.9209627	best: 0.9209756 (406)	total: 2m 3s	remaining: 2m 59s
# 408:	learn: 0.9237335	test: 0.9209846	best: 0.9209846 (408)	total: 2m 3s	remaining: 2m 59s
# 409:	learn: 0.9237769	test: 0.9209170	best: 0.9209846 (408)	total: 2m 4s	remaining: 2m 58s
# 410:	learn: 0.9237857	test: 0.9209980	best: 0.9209980 (410)	total: 2m 4s	remaining: 2m 58s
# 411:	learn: 0.9237879	test: 0.9210292	best: 0.9210292 (411)	total: 2m 4s	remaining: 2m 58s
# 412:	learn: 0.9238094	test: 0.9209000	best: 0.9210292 (411)	total: 2m 5s	remaining: 2m 57s
# 413:	learn: 0.9238199	test: 0.9209356	best: 0.9210292 (411)	total: 2m 5s	remaining: 2m 57s
# 414:	learn: 0.9238512	test: 0.9209998	best: 0.9210292 (411)	total: 2m 5s	remaining: 2m 57s
# 415:	learn: 0.9238811	test: 0.9209232	best: 0.9210292 (411)	total: 2m 6s	remaining: 2m 57s
# 416:	learn: 0.9238998	test: 0.9209541	best: 0.9210292 (411)	total: 2m 6s	remaining: 2m 56s
# 417:	learn: 0.9239363	test: 0.9209891	best: 0.9210292 (411)	total: 2m 6s	remaining: 2m 56s
# 418:	learn: 0.9239704	test: 0.9210512	best: 0.9210512 (418)	total: 2m 7s	remaining: 2m 56s
# 419:	learn: 0.9240014	test: 0.9210475	best: 0.9210512 (418)	total: 2m 7s	remaining: 2m 56s
# 420:	learn: 0.9240350	test: 0.9210354	best: 0.9210512 (418)	total: 2m 7s	remaining: 2m 55s
# 421:	learn: 0.9240401	test: 0.9210740	best: 0.9210740 (421)	total: 2m 8s	remaining: 2m 55s
# 422:	learn: 0.9240649	test: 0.9211135	best: 0.9211135 (422)	total: 2m 8s	remaining: 2m 55s
# 423:	learn: 0.9240954	test: 0.9211433	best: 0.9211433 (423)	total: 2m 8s	remaining: 2m 54s
# 424:	learn: 0.9241046	test: 0.9211412	best: 0.9211433 (423)	total: 2m 9s	remaining: 2m 54s
# 425:	learn: 0.9241664	test: 0.9212421	best: 0.9212421 (425)	total: 2m 9s	remaining: 2m 54s
# 426:	learn: 0.9241898	test: 0.9212582	best: 0.9212582 (426)	total: 2m 9s	remaining: 2m 53s
# 427:	learn: 0.9241976	test: 0.9212321	best: 0.9212582 (426)	total: 2m 9s	remaining: 2m 53s
# 428:	learn: 0.9242221	test: 0.9212161	best: 0.9212582 (426)	total: 2m 10s	remaining: 2m 53s
# 429:	learn: 0.9242504	test: 0.9212386	best: 0.9212582 (426)	total: 2m 10s	remaining: 2m 53s
# 430:	learn: 0.9242512	test: 0.9212887	best: 0.9212887 (430)	total: 2m 10s	remaining: 2m 52s
# 431:	learn: 0.9242489	test: 0.9213042	best: 0.9213042 (431)	total: 2m 11s	remaining: 2m 52s
# 432:	learn: 0.9242598	test: 0.9212721	best: 0.9213042 (431)	total: 2m 11s	remaining: 2m 52s
# 433:	learn: 0.9243211	test: 0.9213072	best: 0.9213072 (433)	total: 2m 11s	remaining: 2m 51s
# 434:	learn: 0.9243292	test: 0.9213290	best: 0.9213290 (434)	total: 2m 12s	remaining: 2m 51s
# 435:	learn: 0.9243352	test: 0.9213064	best: 0.9213290 (434)	total: 2m 12s	remaining: 2m 51s
# 436:	learn: 0.9243699	test: 0.9214123	best: 0.9214123 (436)	total: 2m 12s	remaining: 2m 51s
# 437:	learn: 0.9243755	test: 0.9214647	best: 0.9214647 (437)	total: 2m 13s	remaining: 2m 50s
# 438:	learn: 0.9243815	test: 0.9214500	best: 0.9214647 (437)	total: 2m 13s	remaining: 2m 50s
# 439:	learn: 0.9244081	test: 0.9214499	best: 0.9214647 (437)	total: 2m 13s	remaining: 2m 50s
# 440:	learn: 0.9244081	test: 0.9213909	best: 0.9214647 (437)	total: 2m 13s	remaining: 2m 49s
# 441:	learn: 0.9244368	test: 0.9214139	best: 0.9214647 (437)	total: 2m 14s	remaining: 2m 49s
# 442:	learn: 0.9244707	test: 0.9214201	best: 0.9214647 (437)	total: 2m 14s	remaining: 2m 49s
# 443:	learn: 0.9244708	test: 0.9214280	best: 0.9214647 (437)	total: 2m 14s	remaining: 2m 48s
# 444:	learn: 0.9244929	test: 0.9214741	best: 0.9214741 (444)	total: 2m 15s	remaining: 2m 48s
# 445:	learn: 0.9244874	test: 0.9214378	best: 0.9214741 (444)	total: 2m 15s	remaining: 2m 48s
# 446:	learn: 0.9244904	test: 0.9214153	best: 0.9214741 (444)	total: 2m 15s	remaining: 2m 47s
# 447:	learn: 0.9244922	test: 0.9214322	best: 0.9214741 (444)	total: 2m 15s	remaining: 2m 47s
# 448:	learn: 0.9245212	test: 0.9214998	best: 0.9214998 (448)	total: 2m 16s	remaining: 2m 47s
# 449:	learn: 0.9245605	test: 0.9214918	best: 0.9214998 (448)	total: 2m 16s	remaining: 2m 47s
# 450:	learn: 0.9246186	test: 0.9215108	best: 0.9215108 (450)	total: 2m 17s	remaining: 2m 46s
# 451:	learn: 0.9246789	test: 0.9214376	best: 0.9215108 (450)	total: 2m 17s	remaining: 2m 46s
# 452:	learn: 0.9246557	test: 0.9214257	best: 0.9215108 (450)	total: 2m 17s	remaining: 2m 46s
# 453:	learn: 0.9246820	test: 0.9214972	best: 0.9215108 (450)	total: 2m 18s	remaining: 2m 46s
# 454:	learn: 0.9247054	test: 0.9215039	best: 0.9215108 (450)	total: 2m 18s	remaining: 2m 45s
# 455:	learn: 0.9247188	test: 0.9214555	best: 0.9215108 (450)	total: 2m 18s	remaining: 2m 45s
# 456:	learn: 0.9247384	test: 0.9214750	best: 0.9215108 (450)	total: 2m 19s	remaining: 2m 45s
# 457:	learn: 0.9247894	test: 0.9215577	best: 0.9215577 (457)	total: 2m 19s	remaining: 2m 44s
# 458:	learn: 0.9247956	test: 0.9215728	best: 0.9215728 (458)	total: 2m 19s	remaining: 2m 44s
# 459:	learn: 0.9248527	test: 0.9215927	best: 0.9215927 (459)	total: 2m 19s	remaining: 2m 44s
# 460:	learn: 0.9248466	test: 0.9215887	best: 0.9215927 (459)	total: 2m 20s	remaining: 2m 43s
# 461:	learn: 0.9248504	test: 0.9215541	best: 0.9215927 (459)	total: 2m 20s	remaining: 2m 43s
# 462:	learn: 0.9248933	test: 0.9215793	best: 0.9215927 (459)	total: 2m 20s	remaining: 2m 43s
# 463:	learn: 0.9249098	test: 0.9215618	best: 0.9215927 (459)	total: 2m 21s	remaining: 2m 43s
# 464:	learn: 0.9249040	test: 0.9215727	best: 0.9215927 (459)	total: 2m 21s	remaining: 2m 42s
# 465:	learn: 0.9249303	test: 0.9215712	best: 0.9215927 (459)	total: 2m 21s	remaining: 2m 42s
# 466:	learn: 0.9249717	test: 0.9215945	best: 0.9215945 (466)	total: 2m 22s	remaining: 2m 42s
# 467:	learn: 0.9249997	test: 0.9216469	best: 0.9216469 (467)	total: 2m 22s	remaining: 2m 41s
# 468:	learn: 0.9250324	test: 0.9216055	best: 0.9216469 (467)	total: 2m 22s	remaining: 2m 41s
# 469:	learn: 0.9250376	test: 0.9216017	best: 0.9216469 (467)	total: 2m 23s	remaining: 2m 41s
# 470:	learn: 0.9250519	test: 0.9216284	best: 0.9216469 (467)	total: 2m 23s	remaining: 2m 41s
# 471:	learn: 0.9250589	test: 0.9216906	best: 0.9216906 (471)	total: 2m 23s	remaining: 2m 40s
# 472:	learn: 0.9250830	test: 0.9217188	best: 0.9217188 (472)	total: 2m 24s	remaining: 2m 40s
# 473:	learn: 0.9251046	test: 0.9217463	best: 0.9217463 (473)	total: 2m 24s	remaining: 2m 40s
# 474:	learn: 0.9251344	test: 0.9217511	best: 0.9217511 (474)	total: 2m 24s	remaining: 2m 39s
# 475:	learn: 0.9251311	test: 0.9217348	best: 0.9217511 (474)	total: 2m 24s	remaining: 2m 39s
# 476:	learn: 0.9251245	test: 0.9217218	best: 0.9217511 (474)	total: 2m 25s	remaining: 2m 39s
# 477:	learn: 0.9251406	test: 0.9217460	best: 0.9217511 (474)	total: 2m 25s	remaining: 2m 38s
# 478:	learn: 0.9251520	test: 0.9216795	best: 0.9217511 (474)	total: 2m 25s	remaining: 2m 38s
# 479:	learn: 0.9251646	test: 0.9216461	best: 0.9217511 (474)	total: 2m 26s	remaining: 2m 38s
# 480:	learn: 0.9251555	test: 0.9216468	best: 0.9217511 (474)	total: 2m 26s	remaining: 2m 38s
# 481:	learn: 0.9251574	test: 0.9216700	best: 0.9217511 (474)	total: 2m 26s	remaining: 2m 37s
# 482:	learn: 0.9251500	test: 0.9216604	best: 0.9217511 (474)	total: 2m 27s	remaining: 2m 37s
# 483:	learn: 0.9251625	test: 0.9216766	best: 0.9217511 (474)	total: 2m 27s	remaining: 2m 37s
# 484:	learn: 0.9252073	test: 0.9216573	best: 0.9217511 (474)	total: 2m 27s	remaining: 2m 36s
# 485:	learn: 0.9252542	test: 0.9216652	best: 0.9217511 (474)	total: 2m 27s	remaining: 2m 36s
# 486:	learn: 0.9252987	test: 0.9217051	best: 0.9217511 (474)	total: 2m 28s	remaining: 2m 36s
# 487:	learn: 0.9252939	test: 0.9217394	best: 0.9217511 (474)	total: 2m 28s	remaining: 2m 35s
# 488:	learn: 0.9253110	test: 0.9217399	best: 0.9217511 (474)	total: 2m 29s	remaining: 2m 35s
# 489:	learn: 0.9253504	test: 0.9217051	best: 0.9217511 (474)	total: 2m 29s	remaining: 2m 35s
# 490:	learn: 0.9253397	test: 0.9216900	best: 0.9217511 (474)	total: 2m 29s	remaining: 2m 35s
# 491:	learn: 0.9253569	test: 0.9217158	best: 0.9217511 (474)	total: 2m 30s	remaining: 2m 34s
# 492:	learn: 0.9253606	test: 0.9217192	best: 0.9217511 (474)	total: 2m 30s	remaining: 2m 34s
# 493:	learn: 0.9253892	test: 0.9217347	best: 0.9217511 (474)	total: 2m 30s	remaining: 2m 34s
# 494:	learn: 0.9254191	test: 0.9216795	best: 0.9217511 (474)	total: 2m 30s	remaining: 2m 33s
# 495:	learn: 0.9254329	test: 0.9216759	best: 0.9217511 (474)	total: 2m 31s	remaining: 2m 33s
# 496:	learn: 0.9254204	test: 0.9217020	best: 0.9217511 (474)	total: 2m 31s	remaining: 2m 33s
# 497:	learn: 0.9254259	test: 0.9217325	best: 0.9217511 (474)	total: 2m 31s	remaining: 2m 33s
# 498:	learn: 0.9254436	test: 0.9217224	best: 0.9217511 (474)	total: 2m 32s	remaining: 2m 32s
# 499:	learn: 0.9254318	test: 0.9218046	best: 0.9218046 (499)	total: 2m 32s	remaining: 2m 32s
# 500:	learn: 0.9254673	test: 0.9217848	best: 0.9218046 (499)	total: 2m 32s	remaining: 2m 32s
# 501:	learn: 0.9254912	test: 0.9218247	best: 0.9218247 (501)	total: 2m 33s	remaining: 2m 31s
# 502:	learn: 0.9254986	test: 0.9217895	best: 0.9218247 (501)	total: 2m 33s	remaining: 2m 31s
# 503:	learn: 0.9254913	test: 0.9217917	best: 0.9218247 (501)	total: 2m 33s	remaining: 2m 31s
# 504:	learn: 0.9254982	test: 0.9217934	best: 0.9218247 (501)	total: 2m 34s	remaining: 2m 30s
# 505:	learn: 0.9255065	test: 0.9217903	best: 0.9218247 (501)	total: 2m 34s	remaining: 2m 30s
# 506:	learn: 0.9255226	test: 0.9218055	best: 0.9218247 (501)	total: 2m 34s	remaining: 2m 30s
# 507:	learn: 0.9255317	test: 0.9218297	best: 0.9218297 (507)	total: 2m 34s	remaining: 2m 30s
# 508:	learn: 0.9255748	test: 0.9218623	best: 0.9218623 (508)	total: 2m 35s	remaining: 2m 29s
# 509:	learn: 0.9255899	test: 0.9218707	best: 0.9218707 (509)	total: 2m 35s	remaining: 2m 29s
# 510:	learn: 0.9256517	test: 0.9218870	best: 0.9218870 (510)	total: 2m 35s	remaining: 2m 29s
# 511:	learn: 0.9256589	test: 0.9218974	best: 0.9218974 (511)	total: 2m 36s	remaining: 2m 28s
# 512:	learn: 0.9256596	test: 0.9219216	best: 0.9219216 (512)	total: 2m 36s	remaining: 2m 28s
# 513:	learn: 0.9256743	test: 0.9219777	best: 0.9219777 (513)	total: 2m 36s	remaining: 2m 28s
# 514:	learn: 0.9256836	test: 0.9219363	best: 0.9219777 (513)	total: 2m 37s	remaining: 2m 27s
# 515:	learn: 0.9256858	test: 0.9219284	best: 0.9219777 (513)	total: 2m 37s	remaining: 2m 27s
# 516:	learn: 0.9257023	test: 0.9218960	best: 0.9219777 (513)	total: 2m 37s	remaining: 2m 27s
# 517:	learn: 0.9257274	test: 0.9219106	best: 0.9219777 (513)	total: 2m 38s	remaining: 2m 27s
# 518:	learn: 0.9257527	test: 0.9219046	best: 0.9219777 (513)	total: 2m 38s	remaining: 2m 26s
# 519:	learn: 0.9257602	test: 0.9218766	best: 0.9219777 (513)	total: 2m 38s	remaining: 2m 26s
# 520:	learn: 0.9258196	test: 0.9219455	best: 0.9219777 (513)	total: 2m 39s	remaining: 2m 26s
# 521:	learn: 0.9258226	test: 0.9219185	best: 0.9219777 (513)	total: 2m 39s	remaining: 2m 25s
# 522:	learn: 0.9258605	test: 0.9219819	best: 0.9219819 (522)	total: 2m 39s	remaining: 2m 25s
# 523:	learn: 0.9258534	test: 0.9220296	best: 0.9220296 (523)	total: 2m 40s	remaining: 2m 25s
# 524:	learn: 0.9259194	test: 0.9220021	best: 0.9220296 (523)	total: 2m 40s	remaining: 2m 25s
# 525:	learn: 0.9259160	test: 0.9220190	best: 0.9220296 (523)	total: 2m 40s	remaining: 2m 24s
# 526:	learn: 0.9259122	test: 0.9220716	best: 0.9220716 (526)	total: 2m 41s	remaining: 2m 24s
# 527:	learn: 0.9259344	test: 0.9220448	best: 0.9220716 (526)	total: 2m 41s	remaining: 2m 24s
# ...
# 826:	learn: 0.9294332	test: 0.9239943	best: 0.9240149 (822)	total: 4m 15s	remaining: 53.4s
# 827:	learn: 0.9294268	test: 0.9239988	best: 0.9240149 (822)	total: 4m 15s	remaining: 53.1s
# 828:	learn: 0.9294464	test: 0.9239483	best: 0.9240149 (822)	total: 4m 15s	remaining: 52.8s
# 829:	learn: 0.9294513	test: 0.9239796	best: 0.9240149 (822)	total: 4m 15s	remaining: 52.4s
# 830:	learn: 0.9294601	test: 0.9239982	best: 0.9240149 (822)	total: 4m 16s	remaining: 52.1s
# 831:	learn: 0.9294696	test: 0.9239960	best: 0.9240149 (822)	total: 4m 16s	remaining: 51.8s
# 832:	learn: 0.9294667	test: 0.9239895	best: 0.9240149 (822)	total: 4m 16s	remaining: 51.5s
# 833:	learn: 0.9294815	test: 0.9240047	best: 0.9240149 (822)	total: 4m 17s	remaining: 51.2s
# 834:	learn: 0.9294737	test: 0.9240545	best: 0.9240545 (834)	total: 4m 17s	remaining: 50.9s
# 835:	learn: 0.9295010	test: 0.9240472	best: 0.9240545 (834)	total: 4m 17s	remaining: 50.6s
# 836:	learn: 0.9295195	test: 0.9240174	best: 0.9240545 (834)	total: 4m 18s	remaining: 50.3s
# 837:	learn: 0.9295340	test: 0.9240185	best: 0.9240545 (834)	total: 4m 18s	remaining: 50s
# 838:	learn: 0.9295776	test: 0.9240210	best: 0.9240545 (834)	total: 4m 18s	remaining: 49.6s
# 839:	learn: 0.9296199	test: 0.9240531	best: 0.9240545 (834)	total: 4m 18s	remaining: 49.3s
# 840:	learn: 0.9296598	test: 0.9240970	best: 0.9240970 (840)	total: 4m 19s	remaining: 49s
# 841:	learn: 0.9296708	test: 0.9241170	best: 0.9241170 (841)	total: 4m 19s	remaining: 48.7s
# 842:	learn: 0.9296747	test: 0.9240950	best: 0.9241170 (841)	total: 4m 19s	remaining: 48.4s
# 843:	learn: 0.9296887	test: 0.9240924	best: 0.9241170 (841)	total: 4m 20s	remaining: 48.1s
# 844:	learn: 0.9296970	test: 0.9240808	best: 0.9241170 (841)	total: 4m 20s	remaining: 47.8s
# 845:	learn: 0.9297197	test: 0.9240744	best: 0.9241170 (841)	total: 4m 20s	remaining: 47.4s
# 846:	learn: 0.9297193	test: 0.9240642	best: 0.9241170 (841)	total: 4m 20s	remaining: 47.1s
# 847:	learn: 0.9297385	test: 0.9240800	best: 0.9241170 (841)	total: 4m 21s	remaining: 46.8s
# 848:	learn: 0.9297487	test: 0.9240397	best: 0.9241170 (841)	total: 4m 21s	remaining: 46.5s
# 849:	learn: 0.9297585	test: 0.9240696	best: 0.9241170 (841)	total: 4m 21s	remaining: 46.2s
# 850:	learn: 0.9297561	test: 0.9240732	best: 0.9241170 (841)	total: 4m 22s	remaining: 45.9s
# 851:	learn: 0.9297845	test: 0.9240073	best: 0.9241170 (841)	total: 4m 22s	remaining: 45.6s
# 852:	learn: 0.9298008	test: 0.9240476	best: 0.9241170 (841)	total: 4m 22s	remaining: 45.3s
# 853:	learn: 0.9298064	test: 0.9240526	best: 0.9241170 (841)	total: 4m 23s	remaining: 45s
# 854:	learn: 0.9298000	test: 0.9240402	best: 0.9241170 (841)	total: 4m 23s	remaining: 44.7s
# 855:	learn: 0.9298041	test: 0.9240819	best: 0.9241170 (841)	total: 4m 23s	remaining: 44.4s
# 856:	learn: 0.9298164	test: 0.9240859	best: 0.9241170 (841)	total: 4m 24s	remaining: 44.1s
# 857:	learn: 0.9298352	test: 0.9240839	best: 0.9241170 (841)	total: 4m 24s	remaining: 43.8s
# 858:	learn: 0.9298388	test: 0.9241282	best: 0.9241282 (858)	total: 4m 24s	remaining: 43.5s
# 859:	learn: 0.9299103	test: 0.9241766	best: 0.9241766 (859)	total: 4m 25s	remaining: 43.2s
# 860:	learn: 0.9298973	test: 0.9241808	best: 0.9241808 (860)	total: 4m 25s	remaining: 42.9s
# 861:	learn: 0.9299093	test: 0.9241608	best: 0.9241808 (860)	total: 4m 25s	remaining: 42.6s
# 862:	learn: 0.9299160	test: 0.9241743	best: 0.9241808 (860)	total: 4m 26s	remaining: 42.3s
# 863:	learn: 0.9298937	test: 0.9241329	best: 0.9241808 (860)	total: 4m 26s	remaining: 42s
# 864:	learn: 0.9298912	test: 0.9241309	best: 0.9241808 (860)	total: 4m 26s	remaining: 41.6s
# 865:	learn: 0.9299004	test: 0.9241183	best: 0.9241808 (860)	total: 4m 27s	remaining: 41.3s
# 866:	learn: 0.9299187	test: 0.9241448	best: 0.9241808 (860)	total: 4m 27s	remaining: 41s
# 867:	learn: 0.9299386	test: 0.9241135	best: 0.9241808 (860)	total: 4m 27s	remaining: 40.7s
# 868:	learn: 0.9299757	test: 0.9240961	best: 0.9241808 (860)	total: 4m 28s	remaining: 40.4s
# 869:	learn: 0.9299832	test: 0.9240961	best: 0.9241808 (860)	total: 4m 28s	remaining: 40.1s
# 870:	learn: 0.9299734	test: 0.9240857	best: 0.9241808 (860)	total: 4m 28s	remaining: 39.8s
# 871:	learn: 0.9299733	test: 0.9240986	best: 0.9241808 (860)	total: 4m 28s	remaining: 39.5s
# 872:	learn: 0.9299853	test: 0.9240977	best: 0.9241808 (860)	total: 4m 29s	remaining: 39.2s
# 873:	learn: 0.9300007	test: 0.9241070	best: 0.9241808 (860)	total: 4m 29s	remaining: 38.9s
# 874:	learn: 0.9300029	test: 0.9241388	best: 0.9241808 (860)	total: 4m 29s	remaining: 38.6s
# 875:	learn: 0.9300068	test: 0.9241780	best: 0.9241808 (860)	total: 4m 30s	remaining: 38.3s
# 876:	learn: 0.9300259	test: 0.9241577	best: 0.9241808 (860)	total: 4m 30s	remaining: 37.9s
# 877:	learn: 0.9300363	test: 0.9241501	best: 0.9241808 (860)	total: 4m 30s	remaining: 37.7s
# 878:	learn: 0.9300383	test: 0.9241827	best: 0.9241827 (878)	total: 4m 31s	remaining: 37.3s
# 879:	learn: 0.9300557	test: 0.9241577	best: 0.9241827 (878)	total: 4m 31s	remaining: 37s
# 880:	learn: 0.9300859	test: 0.9242087	best: 0.9242087 (880)	total: 4m 31s	remaining: 36.7s
# 881:	learn: 0.9300958	test: 0.9242340	best: 0.9242340 (881)	total: 4m 32s	remaining: 36.4s
# 882:	learn: 0.9300984	test: 0.9242408	best: 0.9242408 (882)	total: 4m 32s	remaining: 36.1s
# 883:	learn: 0.9300960	test: 0.9242760	best: 0.9242760 (883)	total: 4m 32s	remaining: 35.8s
# 884:	learn: 0.9301034	test: 0.9242822	best: 0.9242822 (884)	total: 4m 33s	remaining: 35.5s
# 885:	learn: 0.9301246	test: 0.9243080	best: 0.9243080 (885)	total: 4m 33s	remaining: 35.2s
# 886:	learn: 0.9301289	test: 0.9243193	best: 0.9243193 (886)	total: 4m 33s	remaining: 34.9s
# 887:	learn: 0.9301488	test: 0.9243590	best: 0.9243590 (887)	total: 4m 33s	remaining: 34.5s
# 888:	learn: 0.9301564	test: 0.9243408	best: 0.9243590 (887)	total: 4m 34s	remaining: 34.2s
# 889:	learn: 0.9301462	test: 0.9243889	best: 0.9243889 (889)	total: 4m 34s	remaining: 33.9s
# 890:	learn: 0.9301618	test: 0.9243907	best: 0.9243907 (890)	total: 4m 34s	remaining: 33.6s
# 891:	learn: 0.9301634	test: 0.9243960	best: 0.9243960 (891)	total: 4m 35s	remaining: 33.3s
# 892:	learn: 0.9301654	test: 0.9244197	best: 0.9244197 (892)	total: 4m 35s	remaining: 33s
# 893:	learn: 0.9301988	test: 0.9244264	best: 0.9244264 (893)	total: 4m 36s	remaining: 32.7s
# 894:	learn: 0.9302293	test: 0.9244172	best: 0.9244264 (893)	total: 4m 36s	remaining: 32.4s
# 895:	learn: 0.9302198	test: 0.9244214	best: 0.9244264 (893)	total: 4m 36s	remaining: 32.1s
# 896:	learn: 0.9302250	test: 0.9244014	best: 0.9244264 (893)	total: 4m 36s	remaining: 31.8s
# 897:	learn: 0.9302435	test: 0.9244189	best: 0.9244264 (893)	total: 4m 37s	remaining: 31.5s
# 898:	learn: 0.9302412	test: 0.9243676	best: 0.9244264 (893)	total: 4m 37s	remaining: 31.2s
# 899:	learn: 0.9302497	test: 0.9244120	best: 0.9244264 (893)	total: 4m 38s	remaining: 30.9s
# 900:	learn: 0.9302614	test: 0.9244391	best: 0.9244391 (900)	total: 4m 38s	remaining: 30.6s
# 901:	learn: 0.9302591	test: 0.9244286	best: 0.9244391 (900)	total: 4m 38s	remaining: 30.3s
# 902:	learn: 0.9302751	test: 0.9244171	best: 0.9244391 (900)	total: 4m 38s	remaining: 30s
# 903:	learn: 0.9302973	test: 0.9243649	best: 0.9244391 (900)	total: 4m 39s	remaining: 29.6s
# 904:	learn: 0.9302888	test: 0.9243634	best: 0.9244391 (900)	total: 4m 39s	remaining: 29.3s
# 905:	learn: 0.9303174	test: 0.9244166	best: 0.9244391 (900)	total: 4m 39s	remaining: 29s
# 906:	learn: 0.9303234	test: 0.9244054	best: 0.9244391 (900)	total: 4m 40s	remaining: 28.7s
# 907:	learn: 0.9303467	test: 0.9243891	best: 0.9244391 (900)	total: 4m 40s	remaining: 28.4s
# 908:	learn: 0.9303636	test: 0.9243945	best: 0.9244391 (900)	total: 4m 40s	remaining: 28.1s
# 909:	learn: 0.9303608	test: 0.9244097	best: 0.9244391 (900)	total: 4m 40s	remaining: 27.8s
# 910:	learn: 0.9303740	test: 0.9244179	best: 0.9244391 (900)	total: 4m 41s	remaining: 27.5s
# 911:	learn: 0.9303530	test: 0.9243901	best: 0.9244391 (900)	total: 4m 41s	remaining: 27.2s
# 912:	learn: 0.9303949	test: 0.9243970	best: 0.9244391 (900)	total: 4m 41s	remaining: 26.8s
# 913:	learn: 0.9304015	test: 0.9244871	best: 0.9244871 (913)	total: 4m 41s	remaining: 26.5s
# 914:	learn: 0.9304251	test: 0.9244868	best: 0.9244871 (913)	total: 4m 42s	remaining: 26.2s
# 915:	learn: 0.9304228	test: 0.9244781	best: 0.9244871 (913)	total: 4m 42s	remaining: 25.9s
# 916:	learn: 0.9304309	test: 0.9244659	best: 0.9244871 (913)	total: 4m 42s	remaining: 25.6s
# 917:	learn: 0.9304478	test: 0.9244885	best: 0.9244885 (917)	total: 4m 43s	remaining: 25.3s
# 918:	learn: 0.9304895	test: 0.9244561	best: 0.9244885 (917)	total: 4m 43s	remaining: 25s
# 919:	learn: 0.9304894	test: 0.9244544	best: 0.9244885 (917)	total: 4m 43s	remaining: 24.7s
# 920:	learn: 0.9304909	test: 0.9244721	best: 0.9244885 (917)	total: 4m 44s	remaining: 24.4s
# 921:	learn: 0.9305014	test: 0.9244668	best: 0.9244885 (917)	total: 4m 44s	remaining: 24.1s
# 922:	learn: 0.9304861	test: 0.9244552	best: 0.9244885 (917)	total: 4m 44s	remaining: 23.8s
# 923:	learn: 0.9305215	test: 0.9245095	best: 0.9245095 (923)	total: 4m 45s	remaining: 23.5s
# 924:	learn: 0.9305226	test: 0.9245058	best: 0.9245095 (923)	total: 4m 45s	remaining: 23.2s
# 925:	learn: 0.9305279	test: 0.9244723	best: 0.9245095 (923)	total: 4m 45s	remaining: 22.8s
# 926:	learn: 0.9305331	test: 0.9244954	best: 0.9245095 (923)	total: 4m 46s	remaining: 22.5s
# 927:	learn: 0.9305441	test: 0.9245207	best: 0.9245207 (927)	total: 4m 46s	remaining: 22.2s
# 928:	learn: 0.9305458	test: 0.9245008	best: 0.9245207 (927)	total: 4m 46s	remaining: 21.9s
# 929:	learn: 0.9305427	test: 0.9244634	best: 0.9245207 (927)	total: 4m 47s	remaining: 21.6s
# 930:	learn: 0.9305440	test: 0.9244682	best: 0.9245207 (927)	total: 4m 47s	remaining: 21.3s
# 931:	learn: 0.9305320	test: 0.9244805	best: 0.9245207 (927)	total: 4m 47s	remaining: 21s
# 932:	learn: 0.9305490	test: 0.9244549	best: 0.9245207 (927)	total: 4m 48s	remaining: 20.7s
# 933:	learn: 0.9305591	test: 0.9244251	best: 0.9245207 (927)	total: 4m 48s	remaining: 20.4s
# 934:	learn: 0.9305657	test: 0.9244490	best: 0.9245207 (927)	total: 4m 48s	remaining: 20.1s
# 935:	learn: 0.9306062	test: 0.9244495	best: 0.9245207 (927)	total: 4m 49s	remaining: 19.8s
# 936:	learn: 0.9306152	test: 0.9244743	best: 0.9245207 (927)	total: 4m 49s	remaining: 19.5s
# 937:	learn: 0.9306246	test: 0.9244766	best: 0.9245207 (927)	total: 4m 49s	remaining: 19.1s
# 938:	learn: 0.9306217	test: 0.9244941	best: 0.9245207 (927)	total: 4m 49s	remaining: 18.8s
# 939:	learn: 0.9306357	test: 0.9244881	best: 0.9245207 (927)	total: 4m 50s	remaining: 18.5s
# 940:	learn: 0.9306627	test: 0.9245377	best: 0.9245377 (940)	total: 4m 50s	remaining: 18.2s
# 941:	learn: 0.9306689	test: 0.9245349	best: 0.9245377 (940)	total: 4m 51s	remaining: 17.9s
# 942:	learn: 0.9306812	test: 0.9245234	best: 0.9245377 (940)	total: 4m 51s	remaining: 17.6s
# 943:	learn: 0.9307118	test: 0.9245164	best: 0.9245377 (940)	total: 4m 51s	remaining: 17.3s
# 944:	learn: 0.9306994	test: 0.9245160	best: 0.9245377 (940)	total: 4m 51s	remaining: 17s
# 945:	learn: 0.9307081	test: 0.9245132	best: 0.9245377 (940)	total: 4m 52s	remaining: 16.7s
# 946:	learn: 0.9307064	test: 0.9245105	best: 0.9245377 (940)	total: 4m 52s	remaining: 16.4s
# 947:	learn: 0.9306961	test: 0.9245071	best: 0.9245377 (940)	total: 4m 52s	remaining: 16.1s
# 948:	learn: 0.9306974	test: 0.9245172	best: 0.9245377 (940)	total: 4m 53s	remaining: 15.8s
# 949:	learn: 0.9307214	test: 0.9245708	best: 0.9245708 (949)	total: 4m 53s	remaining: 15.4s
# 950:	learn: 0.9307429	test: 0.9244939	best: 0.9245708 (949)	total: 4m 53s	remaining: 15.1s
# 951:	learn: 0.9307600	test: 0.9245057	best: 0.9245708 (949)	total: 4m 54s	remaining: 14.8s
# 952:	learn: 0.9307759	test: 0.9245285	best: 0.9245708 (949)	total: 4m 54s	remaining: 14.5s
# 953:	learn: 0.9307660	test: 0.9245704	best: 0.9245708 (949)	total: 4m 54s	remaining: 14.2s
# 954:	learn: 0.9307760	test: 0.9245482	best: 0.9245708 (949)	total: 4m 55s	remaining: 13.9s
# 955:	learn: 0.9307839	test: 0.9245440	best: 0.9245708 (949)	total: 4m 55s	remaining: 13.6s
# 956:	learn: 0.9308086	test: 0.9245420	best: 0.9245708 (949)	total: 4m 55s	remaining: 13.3s
# 957:	learn: 0.9308141	test: 0.9245360	best: 0.9245708 (949)	total: 4m 55s	remaining: 13s
# 958:	learn: 0.9308358	test: 0.9245476	best: 0.9245708 (949)	total: 4m 56s	remaining: 12.7s
# 959:	learn: 0.9308463	test: 0.9245659	best: 0.9245708 (949)	total: 4m 56s	remaining: 12.4s
# 960:	learn: 0.9308840	test: 0.9245793	best: 0.9245793 (960)	total: 4m 56s	remaining: 12.1s
# 961:	learn: 0.9308874	test: 0.9245416	best: 0.9245793 (960)	total: 4m 57s	remaining: 11.7s
# 962:	learn: 0.9308955	test: 0.9245626	best: 0.9245793 (960)	total: 4m 57s	remaining: 11.4s
# 963:	learn: 0.9308903	test: 0.9245717	best: 0.9245793 (960)	total: 4m 57s	remaining: 11.1s
# 964:	learn: 0.9309008	test: 0.9245641	best: 0.9245793 (960)	total: 4m 58s	remaining: 10.8s
# 965:	learn: 0.9309157	test: 0.9245447	best: 0.9245793 (960)	total: 4m 58s	remaining: 10.5s
# 966:	learn: 0.9308941	test: 0.9245402	best: 0.9245793 (960)	total: 4m 58s	remaining: 10.2s
# 967:	learn: 0.9309033	test: 0.9245901	best: 0.9245901 (967)	total: 4m 59s	remaining: 9.89s
# 968:	learn: 0.9309094	test: 0.9245481	best: 0.9245901 (967)	total: 4m 59s	remaining: 9.59s
# 969:	learn: 0.9309296	test: 0.9245588	best: 0.9245901 (967)	total: 4m 59s	remaining: 9.28s
# 970:	learn: 0.9309247	test: 0.9245407	best: 0.9245901 (967)	total: 5m	remaining: 8.96s
# 971:	learn: 0.9309526	test: 0.9245627	best: 0.9245901 (967)	total: 5m	remaining: 8.66s
# 972:	learn: 0.9309579	test: 0.9245405	best: 0.9245901 (967)	total: 5m	remaining: 8.35s
# 973:	learn: 0.9309567	test: 0.9245538	best: 0.9245901 (967)	total: 5m 1s	remaining: 8.04s
# 974:	learn: 0.9309727	test: 0.9246137	best: 0.9246137 (974)	total: 5m 1s	remaining: 7.73s
# 975:	learn: 0.9309858	test: 0.9246445	best: 0.9246445 (975)	total: 5m 1s	remaining: 7.42s
# 976:	learn: 0.9309839	test: 0.9246713	best: 0.9246713 (976)	total: 5m 2s	remaining: 7.11s
# 977:	learn: 0.9309908	test: 0.9246992	best: 0.9246992 (977)	total: 5m 2s	remaining: 6.8s
# 978:	learn: 0.9309876	test: 0.9246930	best: 0.9246992 (977)	total: 5m 2s	remaining: 6.5s
# 979:	learn: 0.9310032	test: 0.9247169	best: 0.9247169 (979)	total: 5m 3s	remaining: 6.18s
# 980:	learn: 0.9310041	test: 0.9246814	best: 0.9247169 (979)	total: 5m 3s	remaining: 5.88s
# 981:	learn: 0.9310047	test: 0.9246707	best: 0.9247169 (979)	total: 5m 3s	remaining: 5.57s
# 982:	learn: 0.9310093	test: 0.9246997	best: 0.9247169 (979)	total: 5m 4s	remaining: 5.26s
# 983:	learn: 0.9310346	test: 0.9246803	best: 0.9247169 (979)	total: 5m 4s	remaining: 4.95s
# 984:	learn: 0.9310504	test: 0.9247636	best: 0.9247636 (984)	total: 5m 4s	remaining: 4.64s
# 985:	learn: 0.9310742	test: 0.9247673	best: 0.9247673 (985)	total: 5m 4s	remaining: 4.33s
# 986:	learn: 0.9310645	test: 0.9247658	best: 0.9247673 (985)	total: 5m 5s	remaining: 4.02s
# 987:	learn: 0.9310904	test: 0.9246937	best: 0.9247673 (985)	total: 5m 5s	remaining: 3.71s
# 988:	learn: 0.9310940	test: 0.9247202	best: 0.9247673 (985)	total: 5m 5s	remaining: 3.4s
# 989:	learn: 0.9311146	test: 0.9247075	best: 0.9247673 (985)	total: 5m 6s	remaining: 3.09s
# 990:	learn: 0.9311298	test: 0.9247250	best: 0.9247673 (985)	total: 5m 6s	remaining: 2.78s
# 991:	learn: 0.9311264	test: 0.9247129	best: 0.9247673 (985)	total: 5m 6s	remaining: 2.47s
# 992:	learn: 0.9311117	test: 0.9247244	best: 0.9247673 (985)	total: 5m 7s	remaining: 2.16s
# 993:	learn: 0.9311274	test: 0.9247086	best: 0.9247673 (985)	total: 5m 7s	remaining: 1.85s
# 994:	learn: 0.9311211	test: 0.9247210	best: 0.9247673 (985)	total: 5m 7s	remaining: 1.55s
# 995:	learn: 0.9311407	test: 0.9247034	best: 0.9247673 (985)	total: 5m 8s	remaining: 1.24s
# 996:	learn: 0.9311656	test: 0.9246994	best: 0.9247673 (985)	total: 5m 8s	remaining: 928ms
# 997:	learn: 0.9311627	test: 0.9247133	best: 0.9247673 (985)	total: 5m 8s	remaining: 619ms
# 998:	learn: 0.9311823	test: 0.9247085	best: 0.9247673 (985)	total: 5m 9s	remaining: 309ms
# 999:	learn: 0.9311911	test: 0.9247405	best: 0.9247673 (985)	total: 5m 9s	remaining: 0us
# bestTest = 0.9247672553
# bestIteration = 985
# Shrink model to first 986 iterations.
# F1 Score on Val Data: 0.92
# F1 Score on Train Data: 0.98
# F1 Score on X_train: 0.97

# %%
# model2 = CatBoostClassifier(num_trees=200,
#                             learning_rate=0.8,
#                             eval_metric='F1')
# model2.fit(train_dataset,
#            eval_set=eval_dataset,
#            init_model=model)

# # Make predictions on the validation data
# preds_proba = model2.predict_proba(data_val)
# preds = np.argmax(preds_proba, axis=1)

# # Calculate F1 score on the training data
# f1_val = f1_score(target_val, preds)
# print(f"F1 Score on Val Data: {f1_val:.2f}")

# # Make predictions on the training data
# preds_proba = model2.predict_proba(data_train)
# preds = np.argmax(preds_proba, axis=1)

# # Calculate F1 score on the training data
# f1_train = f1_score(target_train, preds)
# print(f"F1 Score on Train Data: {f1_train:.2f}")

# # Make predictions on the data
# preds_proba = model2.predict_proba(X_train)
# preds = np.argmax(preds_proba, axis=1)

# # Calculate F1 score on the data
# f1_data = f1_score(y_train, preds)
# print(f"F1 Score on X_train: {f1_data:.2f}")

# %%
test_pred = np.argmax(model.predict_proba(X_test), axis=1)
test_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
print(test_pred.sum())
# Out:
# 572230

# %%
PATH_TO_KAGGLE_SUBMISSION = "/kaggle/working/submission.csv"

submission = pd.DataFrame({"index": test_df["index"], 
                           "exists": test_pred})
submission.to_csv(PATH_TO_KAGGLE_SUBMISSION, index=False)
